# %% [markdown]
# # Scratch baselines without SAM — CustomCNN, ResNet18, ViT
# - Same preprocessing, cosine+warmup schedule, early stopping on AUROC.
# - Final metrics shown at 0.5 and at a *recall‑first* operating point (screening).

# %%
# Clean imports + path setup
import sys, time, warnings
from pathlib import Path
try:
    from tqdm.auto import tqdm
except Exception:
    from tqdm import tqdm
from tqdm import TqdmWarning
warnings.filterwarnings("ignore", category=TqdmWarning)

# Resolve project root (directory containing `src/`)
proj_root = Path.cwd()
for _ in range(5):
    if (proj_root / "src").exists(): break
    proj_root = proj_root.parent
if str(proj_root) not in sys.path:
    sys.path.insert(0, str(proj_root))
print("proj_root:", proj_root)

# Project imports
from src import (
    DataCfg, TrainCfg, build_dataloaders, get_device, set_seed,
    build_custom_cnn, build_resnet18, build_vit_scratch,
    train_model, evaluate, choose_threshold_by_min_recall,
    summarize_at_threshold, plot_curve, plot_two_series, diag_plots,
    add_result, result_registry
)

import numpy as np, torch
set_seed(42)
DEVICE = get_device()
DEVICE
# Out:
# proj_root: /Users/fouadaz/LearningFromUniversity/Learning/DeepLearning_2025/Deep-Learning-Project
# device(type='mps')

# %%
# === Paths/config ===
DATASET_DIR = Path("../Data/chest_xray")  # <--- EDIT THIS IF NEEDED

# Keep split identical across notebooks for fair comparison
data_cfg = DataCfg(
    dataset_dir=DATASET_DIR,
    image_size=224,
    batch_size=32,
    num_workers=0,          # 0 on macOS avoids "MallocStackLogging" noise
    pin_memory=True,
    use_stratified_val=True,
    val_ratio=0.20,         # use the same val split you used elsewhere
    gray_to_rgb=False,      # <<< 1-CHANNEL grayscale
    compute_norm_stats=True,# <<< compute mean/std for 1 channel from train set
    balance_sampler=True
)

train_loader, val_loader, test_loader, info = build_dataloaders(data_cfg, device=DEVICE)
print("Classes:", info["classes"])
print("Lens:", info["n_train"], info["n_val"], info["n_test"])
print("Train counts:", info["train_counts"])

# Class weights: when balance_sampler=True, set None to avoid double-correction
class_weights = None

# Sanity check: confirm 1-channel
xb, yb = next(iter(train_loader))
print("Batch shape:", tuple(xb.shape))  # expect (B, 1, 224, 224)
del xb, yb
# Out:
# Classes: ['NORMAL', 'PNEUMONIA']
# Lens: 4185 1047 624
# Train counts: [1079, 3106]
# Batch shape: (32, 1, 224, 224)

# %%
# Shared training cfg envelope for scratch runs with SAM ON
scratch_sam = TrainCfg(
    epochs=100, patience=15, monitor="va_auroc",
    base_lr=3e-4, weight_decay=0.2,     # <- ViT defaults; CNN/ResNet override below
    clip_grad_norm=1.0, use_amp=False,
    use_sam=True, sam_rho=0.1,          # ViT uses 0.10; CNN/ResNet override below
    use_cosine=True, warmup_epochs=3, min_lr_mult=0.01,
    target_recall=0.95,
    llrd=False, head_lr_mult=1.0
)

# %%
cfg = scratch_sam

cnn = build_custom_cnn(in_chans=1, num_classes=2, width=32, dropout=0.0)  # <<< in_chans=1
t0 = time.time()
cnn_tr, cnn_hist, cnn_time = train_model(
    cnn, train_loader, val_loader, DEVICE, arch="custom_cnn",
    epochs=100, base_lr=0.05, weight_decay=1e-3, label_smoothing=0.05,
    use_sam=True, sam_rho=0.02,   # good rho for small CNNs
    use_cosine=True, warmup_epochs=3, min_lr_mult=0.01,
    monitor="va_auroc", patience=10, clip_grad_norm=1.0,
    class_weights=class_weights, llrd=False, head_lr_mult=1.0, use_amp=False,
    tag="CustomCNN-scratch+SAM-1ch"
)
cnn_time = time.time() - t0

plot_curve(cnn_hist['tr_loss'], cnn_hist['va_loss'], "CustomCNN (1ch, SAM) — Loss")
plot_two_series(cnn_hist['va_acc'], "Val Acc", cnn_hist['va_f1'], "Val F1", "CustomCNN (1ch, SAM) — Val")

va = evaluate(cnn_tr, val_loader, DEVICE)
thr, *_ = choose_threshold_by_min_recall(va["targets"], va["probs"][:,1], cfg.target_recall)
te = evaluate(cnn_tr, test_loader, DEVICE)
sum_05   = summarize_at_threshold(te["targets"], te["probs"][:,1], 0.5)
sum_reca = summarize_at_threshold(te["targets"], te["probs"][:,1], thr)
print("[CustomCNN-1ch+SAM @0.5]", {k: round(v,4) for k,v in sum_05.items()})
print("[CustomCNN-1ch+SAM @Rec]", {k: round(v,4) for k,v in sum_reca.items()})
diag_plots("CustomCNN (scratch+SAM, 1ch)", te["probs"], te["targets"], thr, auroc=te.get("auroc"))
add_result("CustomCNN (scratch+SAM, 1ch)", cnn_tr, sum_05, sum_reca, threshold=thr, time_sec=cnn_time)
# Out:
# [CustomCNN-scratch+SAM-1ch] epoch 01/100  tr_loss=0.4757  val_loss=0.5055  val_acc=0.7880  val_f1=0.8360  val_auroc=0.9322  (no_improve=0)
# [CustomCNN-scratch+SAM-1ch] epoch 02/100  tr_loss=0.4482  val_loss=0.5556  val_acc=0.8061  val_f1=0.8515  val_auroc=0.9416  (no_improve=0)
# [CustomCNN-scratch+SAM-1ch] epoch 03/100  tr_loss=0.4506  val_loss=0.3699  val_acc=0.8768  val_f1=0.9123  val_auroc=0.9384  (no_improve=1)
# [CustomCNN-scratch+SAM-1ch] epoch 04/100  tr_loss=0.4159  val_loss=0.4450  val_acc=0.8453  val_f1=0.8862  val_auroc=0.9391  (no_improve=2)
# [CustomCNN-scratch+SAM-1ch] epoch 05/100  tr_loss=0.4256  val_loss=0.3917  val_acc=0.8663  val_f1=0.9026  val_auroc=0.9546  (no_improve=0)
# [CustomCNN-scratch+SAM-1ch] epoch 06/100  tr_loss=0.4035  val_loss=0.4215  val_acc=0.8615  val_f1=0.8990  val_auroc=0.9375  (no_improve=1)
# [CustomCNN-scratch+SAM-1ch] epoch 07/100  tr_loss=0.3885  val_loss=0.3537  val_acc=0.8644  val_f1=0.9111  val_auroc=0.9417  (no_improve=2)
# [CustomCNN-scratch+SAM-1ch] epoch 08/100  tr_loss=0.3897  val_loss=0.3960  val_acc=0.8567  val_f1=0.8950  val_auroc=0.9546  (no_improve=3)
# [CustomCNN-scratch+SAM-1ch] epoch 09/100  tr_loss=0.4018  val_loss=0.3049  val_acc=0.8949  val_f1=0.9265  val_auroc=0.9564  (no_improve=0)
# [CustomCNN-scratch+SAM-1ch] epoch 10/100  tr_loss=0.3792  val_loss=0.9540  val_acc=0.7574  val_f1=0.8061  val_auroc=0.9491  (no_improve=1)
# [CustomCNN-scratch+SAM-1ch] epoch 11/100  tr_loss=0.3877  val_loss=0.5248  val_acc=0.8099  val_f1=0.8546  val_auroc=0.9648  (no_improve=0)
# [CustomCNN-scratch+SAM-1ch] epoch 12/100  tr_loss=0.3883  val_loss=0.3746  val_acc=0.8777  val_f1=0.9124  val_auroc=0.9422  (no_improve=1)
# [CustomCNN-scratch+SAM-1ch] epoch 13/100  tr_loss=0.3847  val_loss=0.3479  val_acc=0.8500  val_f1=0.9072  val_auroc=0.9618  (no_improve=2)
# [CustomCNN-scratch+SAM-1ch] epoch 14/100  tr_loss=0.3751  val_loss=1.8255  val_acc=0.5119  val_f1=0.5110  val_auroc=0.8894  (no_improve=3)
# [CustomCNN-scratch+SAM-1ch] epoch 15/100  tr_loss=0.3853  val_loss=0.6322  val_acc=0.6151  val_f1=0.6570  val_auroc=0.8912  (no_improve=4)
# [CustomCNN-scratch+SAM-1ch] epoch 16/100  tr_loss=0.3829  val_loss=0.5078  val_acc=0.8367  val_f1=0.8778  val_auroc=0.9644  (no_improve=5)
# [CustomCNN-scratch+SAM-1ch] epoch 17/100  tr_loss=0.3789  val_loss=0.4795  val_acc=0.8128  val_f1=0.8594  val_auroc=0.9369  (no_improve=6)
# [CustomCNN-scratch+SAM-1ch] epoch 18/100  tr_loss=0.3795  val_loss=0.3295  val_acc=0.8930  val_f1=0.9280  val_auroc=0.9536  (no_improve=7)
# [CustomCNN-scratch+SAM-1ch] epoch 19/100  tr_loss=0.3704  val_loss=0.3034  val_acc=0.8959  val_f1=0.9265  val_auroc=0.9679  (no_improve=0)
# [CustomCNN-scratch+SAM-1ch] epoch 20/100  tr_loss=0.3496  val_loss=0.3192  val_acc=0.9054  val_f1=0.9337  val_auroc=0.9682  (no_improve=0)
# [CustomCNN-scratch+SAM-1ch] epoch 21/100  tr_loss=0.3568  val_loss=0.3770  val_acc=0.8185  val_f1=0.8894  val_auroc=0.9486  (no_improve=1)
# [CustomCNN-scratch+SAM-1ch] epoch 22/100  tr_loss=0.3551  val_loss=0.3455  val_acc=0.8892  val_f1=0.9209  val_auroc=0.9574  (no_improve=2)
# [CustomCNN-scratch+SAM-1ch] epoch 23/100  tr_loss=0.3848  val_loss=0.4289  val_acc=0.8644  val_f1=0.9007  val_auroc=0.9569  (no_improve=3)
# [CustomCNN-scratch+SAM-1ch] epoch 24/100  tr_loss=0.3462  val_loss=0.3173  val_acc=0.8911  val_f1=0.9222  val_auroc=0.9663  (no_improve=4)
# [CustomCNN-scratch+SAM-1ch] epoch 25/100  tr_loss=0.3466  val_loss=0.8162  val_acc=0.4900  val_f1=0.4775  val_auroc=0.9521  (no_improve=5)
# [CustomCNN-scratch+SAM-1ch] epoch 26/100  tr_loss=0.3511  val_loss=0.3007  val_acc=0.8930  val_f1=0.9234  val_auroc=0.9782  (no_improve=0)
# [CustomCNN-scratch+SAM-1ch] epoch 27/100  tr_loss=0.3571  val_loss=0.4048  val_acc=0.8243  val_f1=0.8669  val_auroc=0.9785  (no_improve=0)
# [CustomCNN-scratch+SAM-1ch] epoch 28/100  tr_loss=0.3516  val_loss=1.3999  val_acc=0.5740  val_f1=0.5975  val_auroc=0.8533  (no_improve=1)
# [CustomCNN-scratch+SAM-1ch] epoch 29/100  tr_loss=0.3481  val_loss=0.3495  val_acc=0.9179  val_f1=0.9425  val_auroc=0.9774  (no_improve=2)
# [CustomCNN-scratch+SAM-1ch] epoch 30/100  tr_loss=0.3380  val_loss=0.4607  val_acc=0.8329  val_f1=0.8746  val_auroc=0.9736  (no_improve=3)
# [CustomCNN-scratch+SAM-1ch] epoch 31/100  tr_loss=0.3416  val_loss=0.3337  val_acc=0.9045  val_f1=0.9353  val_auroc=0.9520  (no_improve=4)
# [CustomCNN-scratch+SAM-1ch] epoch 32/100  tr_loss=0.3381  val_loss=0.2923  val_acc=0.9093  val_f1=0.9355  val_auroc=0.9793  (no_improve=0)
# [CustomCNN-scratch+SAM-1ch] epoch 33/100  tr_loss=0.3460  val_loss=0.2967  val_acc=0.9016  val_f1=0.9299  val_auroc=0.9795  (no_improve=0)
# [CustomCNN-scratch+SAM-1ch] epoch 34/100  tr_loss=0.3490  val_loss=1.5912  val_acc=0.3935  val_f1=0.3090  val_auroc=0.7730  (no_improve=1)
# [CustomCNN-scratch+SAM-1ch] epoch 35/100  tr_loss=0.3407  val_loss=0.6240  val_acc=0.7775  val_f1=0.8244  val_auroc=0.9723  (no_improve=2)
# [CustomCNN-scratch+SAM-1ch] epoch 36/100  tr_loss=0.3441  val_loss=4.6627  val_acc=0.3868  val_f1=0.3082  val_auroc=0.4384  (no_improve=3)
# [CustomCNN-scratch+SAM-1ch] epoch 37/100  tr_loss=0.3428  val_loss=3.5053  val_acc=0.3171  val_f1=0.1478  val_auroc=0.5832  (no_improve=4)
# [CustomCNN-scratch+SAM-1ch] epoch 38/100  tr_loss=0.3316  val_loss=3.0390  val_acc=0.3601  val_f1=0.2421  val_auroc=0.4888  (no_improve=5)
# [CustomCNN-scratch+SAM-1ch] epoch 39/100  tr_loss=0.3289  val_loss=0.5806  val_acc=0.7603  val_f1=0.8077  val_auroc=0.9724  (no_improve=6)
# [CustomCNN-scratch+SAM-1ch] epoch 40/100  tr_loss=0.3479  val_loss=0.2914  val_acc=0.8988  val_f1=0.9282  val_auroc=0.9754  (no_improve=7)
# [CustomCNN-scratch+SAM-1ch] epoch 41/100  tr_loss=0.3316  val_loss=0.2920  val_acc=0.9035  val_f1=0.9313  val_auroc=0.9807  (no_improve=0)
# [CustomCNN-scratch+SAM-1ch] epoch 42/100  tr_loss=0.3459  val_loss=2.0288  val_acc=0.3171  val_f1=0.1478  val_auroc=0.6541  (no_improve=1)
# [CustomCNN-scratch+SAM-1ch] epoch 43/100  tr_loss=0.3197  val_loss=0.5384  val_acc=0.7641  val_f1=0.8122  val_auroc=0.9754  (no_improve=2)
# [CustomCNN-scratch+SAM-1ch] epoch 44/100  tr_loss=0.3278  val_loss=0.4764  val_acc=0.8185  val_f1=0.8617  val_auroc=0.9742  (no_improve=3)
# [CustomCNN-scratch+SAM-1ch] epoch 45/100  tr_loss=0.3290  val_loss=0.2495  val_acc=0.9427  val_f1=0.9611  val_auroc=0.9783  (no_improve=4)
# [CustomCNN-scratch+SAM-1ch] epoch 46/100  tr_loss=0.3182  val_loss=4.6275  val_acc=0.3754  val_f1=0.2749  val_auroc=0.5074  (no_improve=5)
# [CustomCNN-scratch+SAM-1ch] epoch 47/100  tr_loss=0.3341  val_loss=0.3528  val_acc=0.8863  val_f1=0.9183  val_auroc=0.9656  (no_improve=6)
# [CustomCNN-scratch+SAM-1ch] epoch 48/100  tr_loss=0.3400  val_loss=0.3058  val_acc=0.8997  val_f1=0.9288  val_auroc=0.9658  (no_improve=7)
# [CustomCNN-scratch+SAM-1ch] epoch 49/100  tr_loss=0.3120  val_loss=0.3591  val_acc=0.8768  val_f1=0.9106  val_auroc=0.9756  (no_improve=8)
# [CustomCNN-scratch+SAM-1ch] epoch 50/100  tr_loss=0.3096  val_loss=0.2968  val_acc=0.9016  val_f1=0.9296  val_auroc=0.9840  (no_improve=0)
# [CustomCNN-scratch+SAM-1ch] epoch 51/100  tr_loss=0.3215  val_loss=0.2497  val_acc=0.9293  val_f1=0.9512  val_auroc=0.9823  (no_improve=1)
# [CustomCNN-scratch+SAM-1ch] epoch 52/100  tr_loss=0.3240  val_loss=0.3457  val_acc=0.8806  val_f1=0.9131  val_auroc=0.9839  (no_improve=2)
# [CustomCNN-scratch+SAM-1ch] epoch 53/100  tr_loss=0.3041  val_loss=0.3325  val_acc=0.8835  val_f1=0.9157  val_auroc=0.9831  (no_improve=3)
# [CustomCNN-scratch+SAM-1ch] epoch 54/100  tr_loss=0.3172  val_loss=0.3274  val_acc=0.9016  val_f1=0.9299  val_auroc=0.9693  (no_improve=4)
# [CustomCNN-scratch+SAM-1ch] epoch 55/100  tr_loss=0.3022  val_loss=0.4140  val_acc=0.8653  val_f1=0.9016  val_auroc=0.9631  (no_improve=5)
# [CustomCNN-scratch+SAM-1ch] epoch 56/100  tr_loss=0.3127  val_loss=0.4521  val_acc=0.8462  val_f1=0.8861  val_auroc=0.9635  (no_improve=6)
# [CustomCNN-scratch+SAM-1ch] epoch 57/100  tr_loss=0.3068  val_loss=3.6288  val_acc=0.3333  val_f1=0.1846  val_auroc=0.3651  (no_improve=7)
# [CustomCNN-scratch+SAM-1ch] epoch 58/100  tr_loss=0.2971  val_loss=0.3117  val_acc=0.8959  val_f1=0.9255  val_auroc=0.9816  (no_improve=8)
# [CustomCNN-scratch+SAM-1ch] epoch 59/100  tr_loss=0.2995  val_loss=0.3168  val_acc=0.9054  val_f1=0.9326  val_auroc=0.9887  (no_improve=0)
# [CustomCNN-scratch+SAM-1ch] epoch 60/100  tr_loss=0.3145  val_loss=0.4146  val_acc=0.8338  val_f1=0.8750  val_auroc=0.9742  (no_improve=1)
# [CustomCNN-scratch+SAM-1ch] epoch 61/100  tr_loss=0.3010  val_loss=0.4284  val_acc=0.8319  val_f1=0.8732  val_auroc=0.9710  (no_improve=2)
# [CustomCNN-scratch+SAM-1ch] epoch 62/100  tr_loss=0.3078  val_loss=0.2426  val_acc=0.9494  val_f1=0.9658  val_auroc=0.9787  (no_improve=3)
# [CustomCNN-scratch+SAM-1ch] epoch 63/100  tr_loss=0.3032  val_loss=0.3054  val_acc=0.9026  val_f1=0.9304  val_auroc=0.9838  (no_improve=4)
# [CustomCNN-scratch+SAM-1ch] epoch 64/100  tr_loss=0.3013  val_loss=0.3351  val_acc=0.8787  val_f1=0.9121  val_auroc=0.9820  (no_improve=5)
# [CustomCNN-scratch+SAM-1ch] epoch 65/100  tr_loss=0.3041  val_loss=0.2348  val_acc=0.9370  val_f1=0.9563  val_auroc=0.9856  (no_improve=6)
# [CustomCNN-scratch+SAM-1ch] epoch 66/100  tr_loss=0.2971  val_loss=0.4353  val_acc=0.8386  val_f1=0.8790  val_auroc=0.9763  (no_improve=7)
# [CustomCNN-scratch+SAM-1ch] epoch 67/100  tr_loss=0.2926  val_loss=1.7324  val_acc=0.3801  val_f1=0.2845  val_auroc=0.6694  (no_improve=8)
# [CustomCNN-scratch+SAM-1ch] epoch 68/100  tr_loss=0.3010  val_loss=0.4394  val_acc=0.7947  val_f1=0.8409  val_auroc=0.9707  (no_improve=9)
# [CustomCNN-scratch+SAM-1ch] epoch 69/100  tr_loss=0.2949  val_loss=0.3877  val_acc=0.8691  val_f1=0.9037  val_auroc=0.9901  (no_improve=0)
# [CustomCNN-scratch+SAM-1ch] epoch 70/100  tr_loss=0.2815  val_loss=0.2589  val_acc=0.9217  val_f1=0.9449  val_auroc=0.9884  (no_improve=1)
# [CustomCNN-scratch+SAM-1ch] epoch 71/100  tr_loss=0.2779  val_loss=0.3110  val_acc=0.9035  val_f1=0.9311  val_auroc=0.9839  (no_improve=2)
# [CustomCNN-scratch+SAM-1ch] epoch 72/100  tr_loss=0.2813  val_loss=0.4149  val_acc=0.8634  val_f1=0.8992  val_auroc=0.9869  (no_improve=3)
# [CustomCNN-scratch+SAM-1ch] epoch 73/100  tr_loss=0.2850  val_loss=0.3819  val_acc=0.8539  val_f1=0.8920  val_auroc=0.9800  (no_improve=4)
# [CustomCNN-scratch+SAM-1ch] epoch 74/100  tr_loss=0.2849  val_loss=0.2775  val_acc=0.9131  val_f1=0.9384  val_auroc=0.9886  (no_improve=5)
# [CustomCNN-scratch+SAM-1ch] epoch 75/100  tr_loss=0.2798  val_loss=0.2891  val_acc=0.9131  val_f1=0.9385  val_auroc=0.9875  (no_improve=6)
# [CustomCNN-scratch+SAM-1ch] epoch 76/100  tr_loss=0.2742  val_loss=0.2627  val_acc=0.9255  val_f1=0.9474  val_auroc=0.9930  (no_improve=0)
# [CustomCNN-scratch+SAM-1ch] epoch 77/100  tr_loss=0.2755  val_loss=0.2423  val_acc=0.9303  val_f1=0.9512  val_auroc=0.9901  (no_improve=1)
# [CustomCNN-scratch+SAM-1ch] epoch 78/100  tr_loss=0.2730  val_loss=0.5786  val_acc=0.7144  val_f1=0.7621  val_auroc=0.9831  (no_improve=2)
# [CustomCNN-scratch+SAM-1ch] epoch 79/100  tr_loss=0.2696  val_loss=0.2236  val_acc=0.9503  val_f1=0.9658  val_auroc=0.9892  (no_improve=3)
# [CustomCNN-scratch+SAM-1ch] epoch 80/100  tr_loss=0.2781  val_loss=0.2892  val_acc=0.9054  val_f1=0.9327  val_auroc=0.9874  (no_improve=4)
# [CustomCNN-scratch+SAM-1ch] epoch 81/100  tr_loss=0.2702  val_loss=0.2377  val_acc=0.9360  val_f1=0.9554  val_auroc=0.9899  (no_improve=5)
# [CustomCNN-scratch+SAM-1ch] epoch 82/100  tr_loss=0.2697  val_loss=0.2818  val_acc=0.9064  val_f1=0.9331  val_auroc=0.9902  (no_improve=6)
# [CustomCNN-scratch+SAM-1ch] epoch 83/100  tr_loss=0.2731  val_loss=0.2447  val_acc=0.9379  val_f1=0.9568  val_auroc=0.9914  (no_improve=7)
# [CustomCNN-scratch+SAM-1ch] epoch 84/100  tr_loss=0.2690  val_loss=0.2355  val_acc=0.9360  val_f1=0.9554  val_auroc=0.9916  (no_improve=8)
# [CustomCNN-scratch+SAM-1ch] epoch 85/100  tr_loss=0.2624  val_loss=0.2528  val_acc=0.9312  val_f1=0.9518  val_auroc=0.9905  (no_improve=9)
# [CustomCNN-scratch+SAM-1ch] epoch 86/100  tr_loss=0.2726  val_loss=0.2357  val_acc=0.9360  val_f1=0.9554  val_auroc=0.9928  (no_improve=10)
# [CustomCNN-scratch+SAM-1ch] early stopping at epoch 86.
# [CustomCNN-1ch+SAM @0.5] {'acc': 0.9199, 'precision': 0.9067, 'recall': 0.9718, 'f1': 0.9381, 'auroc': 0.9548, 'thr': 0.5}
# [CustomCNN-1ch+SAM @Rec] {'acc': 0.875, 'precision': 0.8362, 'recall': 0.9949, 'f1': 0.9087, 'auroc': 0.9548, 'thr': 0.2085}
# {'summary@0.5': {'acc': 0.9198717948717948,
#   'precision': 0.9066985645933014,
#   'recall': 0.9717948717948718,
#   'f1': 0.9381188118811881,
#   'auroc': 0.9548433048433049,
#   'thr': 0.5},
#  'summary@recall': {'acc': 0.875,
#   'precision': 0.8362068965517241,
#   'recall': 0.9948717948717949,
#   'f1': 0.9086651053864169,
#   'auroc': 0.9548433048433049,
#   'thr': 0.2085},
#  'threshold': 0.2085,
#  'time_sec': 13588.896445989609,
#  'params': 481122}

# %%
rn = build_resnet18(in_chans=1, num_classes=2, pretrained=False, conv_stem=False)  # <<< in_chans=1
t0 = time.time()
rn_tr, rn_hist, rn_time = train_model(
    rn, train_loader, val_loader, DEVICE, arch="resnet18",
    epochs=90, base_lr=0.1, weight_decay=1e-3, label_smoothing=0.05,
    use_sam=True, sam_rho=0.05,  # robust rho for ResNet-18
    use_cosine=True, warmup_epochs=3, min_lr_mult=0.01,
    monitor="va_auroc", patience=10, clip_grad_norm=1.0,
    class_weights=class_weights, llrd=False, head_lr_mult=1.0, use_amp=False,
    tag="ResNet18-scratch+SAM-1ch"
)
rn_time = time.time() - t0

plot_curve(rn_hist['tr_loss'], rn_hist['va_loss'], "ResNet18 (1ch, SAM) — Loss")
plot_two_series(rn_hist['va_acc'], "Val Acc", rn_hist['va_f1'], "Val F1", "ResNet18 (1ch, SAM) — Val")

va = evaluate(rn_tr, val_loader, DEVICE)
thr, *_ = choose_threshold_by_min_recall(va["targets"], va["probs"][:,1], cfg.target_recall)
te = evaluate(rn_tr, test_loader, DEVICE)
sum_05   = summarize_at_threshold(te["targets"], te["probs"][:,1], 0.5)
sum_reca = summarize_at_threshold(te["targets"], te["probs"][:,1], thr)
print("[ResNet18-1ch+SAM @0.5]", {k: round(v,4) for k,v in sum_05.items()})
print("[ResNet18-1ch+SAM @Rec]", {k: round(v,4) for k,v in sum_reca.items()})
diag_plots("ResNet18 (scratch+SAM, 1ch)", te["probs"], te["targets"], thr, auroc=te.get("auroc"))
add_result("ResNet18 (scratch+SAM, 1ch)", rn_tr, sum_05, sum_reca, threshold=thr, time_sec=rn_time)
# Out:
# [ResNet18-scratch+SAM-1ch] epoch 01/90  tr_loss=0.5098  val_loss=0.3107  val_acc=0.8930  val_f1=0.9254  val_auroc=0.9585  (no_improve=0)
# [ResNet18-scratch+SAM-1ch] epoch 02/90  tr_loss=0.5338  val_loss=0.3884  val_acc=0.8672  val_f1=0.9170  val_auroc=0.9607  (no_improve=0)
# [ResNet18-scratch+SAM-1ch] epoch 03/90  tr_loss=0.5715  val_loss=0.3816  val_acc=0.8529  val_f1=0.8954  val_auroc=0.9223  (no_improve=1)
# [ResNet18-scratch+SAM-1ch] epoch 04/90  tr_loss=0.4296  val_loss=0.3317  val_acc=0.8921  val_f1=0.9235  val_auroc=0.9644  (no_improve=0)
# [ResNet18-scratch+SAM-1ch] epoch 05/90  tr_loss=0.4215  val_loss=0.6679  val_acc=0.6972  val_f1=0.7446  val_auroc=0.9658  (no_improve=0)
# [ResNet18-scratch+SAM-1ch] epoch 06/90  tr_loss=0.4158  val_loss=0.4197  val_acc=0.8281  val_f1=0.8703  val_auroc=0.9618  (no_improve=1)
# [ResNet18-scratch+SAM-1ch] epoch 07/90  tr_loss=0.3878  val_loss=0.4364  val_acc=0.8157  val_f1=0.8606  val_auroc=0.9605  (no_improve=2)
# [ResNet18-scratch+SAM-1ch] epoch 08/90  tr_loss=0.3964  val_loss=0.3356  val_acc=0.8816  val_f1=0.9151  val_auroc=0.9693  (no_improve=0)
# [ResNet18-scratch+SAM-1ch] epoch 09/90  tr_loss=0.3763  val_loss=0.4551  val_acc=0.8481  val_f1=0.8870  val_auroc=0.9774  (no_improve=0)
# [ResNet18-scratch+SAM-1ch] epoch 10/90  tr_loss=0.3719  val_loss=0.2962  val_acc=0.9016  val_f1=0.9307  val_auroc=0.9755  (no_improve=1)
# [ResNet18-scratch+SAM-1ch] epoch 11/90  tr_loss=0.3666  val_loss=0.4342  val_acc=0.8147  val_f1=0.8582  val_auroc=0.9771  (no_improve=2)
# [ResNet18-scratch+SAM-1ch] epoch 12/90  tr_loss=0.3749  val_loss=0.3170  val_acc=0.8825  val_f1=0.9172  val_auroc=0.9588  (no_improve=3)
# [ResNet18-scratch+SAM-1ch] epoch 13/90  tr_loss=0.3687  val_loss=0.3558  val_acc=0.8567  val_f1=0.8945  val_auroc=0.9808  (no_improve=0)
# [ResNet18-scratch+SAM-1ch] epoch 14/90  tr_loss=0.3604  val_loss=0.2778  val_acc=0.9131  val_f1=0.9394  val_auroc=0.9736  (no_improve=1)
# [ResNet18-scratch+SAM-1ch] epoch 15/90  tr_loss=0.3671  val_loss=0.3078  val_acc=0.8978  val_f1=0.9270  val_auroc=0.9784  (no_improve=2)
# [ResNet18-scratch+SAM-1ch] epoch 16/90  tr_loss=0.3486  val_loss=0.3368  val_acc=0.8711  val_f1=0.9059  val_auroc=0.9782  (no_improve=3)
# [ResNet18-scratch+SAM-1ch] epoch 17/90  tr_loss=0.3484  val_loss=0.3254  val_acc=0.8758  val_f1=0.9110  val_auroc=0.9714  (no_improve=4)
# [ResNet18-scratch+SAM-1ch] epoch 18/90  tr_loss=0.3446  val_loss=0.2725  val_acc=0.9207  val_f1=0.9446  val_auroc=0.9747  (no_improve=5)
# [ResNet18-scratch+SAM-1ch] epoch 19/90  tr_loss=0.3534  val_loss=0.3254  val_acc=0.8930  val_f1=0.9230  val_auroc=0.9753  (no_improve=6)
# [ResNet18-scratch+SAM-1ch] epoch 20/90  tr_loss=0.3484  val_loss=0.4634  val_acc=0.8128  val_f1=0.8561  val_auroc=0.9825  (no_improve=0)
# [ResNet18-scratch+SAM-1ch] epoch 21/90  tr_loss=0.3542  val_loss=0.4063  val_acc=0.8415  val_f1=0.8816  val_auroc=0.9719  (no_improve=1)
# [ResNet18-scratch+SAM-1ch] epoch 22/90  tr_loss=0.3494  val_loss=0.2980  val_acc=0.8892  val_f1=0.9202  val_auroc=0.9806  (no_improve=2)
# [ResNet18-scratch+SAM-1ch] epoch 23/90  tr_loss=0.3479  val_loss=0.3330  val_acc=0.8863  val_f1=0.9179  val_auroc=0.9757  (no_improve=3)
# [ResNet18-scratch+SAM-1ch] epoch 24/90  tr_loss=0.3457  val_loss=0.2364  val_acc=0.9465  val_f1=0.9636  val_auroc=0.9846  (no_improve=0)
# [ResNet18-scratch+SAM-1ch] epoch 25/90  tr_loss=0.3621  val_loss=0.2837  val_acc=0.9179  val_f1=0.9422  val_auroc=0.9794  (no_improve=1)
# [ResNet18-scratch+SAM-1ch] epoch 26/90  tr_loss=0.3611  val_loss=0.2664  val_acc=0.9188  val_f1=0.9432  val_auroc=0.9801  (no_improve=2)
# [ResNet18-scratch+SAM-1ch] epoch 27/90  tr_loss=0.3384  val_loss=0.2418  val_acc=0.9284  val_f1=0.9509  val_auroc=0.9807  (no_improve=3)
# [ResNet18-scratch+SAM-1ch] epoch 28/90  tr_loss=0.3482  val_loss=0.2392  val_acc=0.9408  val_f1=0.9590  val_auroc=0.9851  (no_improve=0)
# [ResNet18-scratch+SAM-1ch] epoch 29/90  tr_loss=0.3299  val_loss=0.4078  val_acc=0.8472  val_f1=0.8864  val_auroc=0.9648  (no_improve=1)
# [ResNet18-scratch+SAM-1ch] epoch 30/90  tr_loss=0.3492  val_loss=0.2751  val_acc=0.9198  val_f1=0.9432  val_auroc=0.9881  (no_improve=0)
# [ResNet18-scratch+SAM-1ch] epoch 31/90  tr_loss=0.3275  val_loss=0.2447  val_acc=0.9274  val_f1=0.9493  val_auroc=0.9850  (no_improve=1)
# [ResNet18-scratch+SAM-1ch] epoch 32/90  tr_loss=0.3275  val_loss=0.5815  val_acc=0.7603  val_f1=0.8085  val_auroc=0.9631  (no_improve=2)
# [ResNet18-scratch+SAM-1ch] epoch 33/90  tr_loss=0.3393  val_loss=0.2661  val_acc=0.9083  val_f1=0.9349  val_auroc=0.9895  (no_improve=0)
# [ResNet18-scratch+SAM-1ch] epoch 34/90  tr_loss=0.3291  val_loss=0.4127  val_acc=0.8500  val_f1=0.8884  val_auroc=0.9837  (no_improve=1)
# [ResNet18-scratch+SAM-1ch] epoch 35/90  tr_loss=0.3377  val_loss=0.3248  val_acc=0.8835  val_f1=0.9155  val_auroc=0.9848  (no_improve=2)
# [ResNet18-scratch+SAM-1ch] epoch 36/90  tr_loss=0.3206  val_loss=0.2986  val_acc=0.8988  val_f1=0.9273  val_auroc=0.9895  (no_improve=3)
# [ResNet18-scratch+SAM-1ch] epoch 37/90  tr_loss=0.3161  val_loss=0.3088  val_acc=0.8930  val_f1=0.9231  val_auroc=0.9857  (no_improve=4)
# [ResNet18-scratch+SAM-1ch] epoch 38/90  tr_loss=0.3256  val_loss=0.3239  val_acc=0.8835  val_f1=0.9154  val_auroc=0.9887  (no_improve=5)
# [ResNet18-scratch+SAM-1ch] epoch 39/90  tr_loss=0.3073  val_loss=0.2551  val_acc=0.9226  val_f1=0.9455  val_auroc=0.9906  (no_improve=0)
# [ResNet18-scratch+SAM-1ch] epoch 40/90  tr_loss=0.3199  val_loss=0.3405  val_acc=0.8720  val_f1=0.9062  val_auroc=0.9895  (no_improve=1)
# [ResNet18-scratch+SAM-1ch] epoch 41/90  tr_loss=0.3236  val_loss=0.2332  val_acc=0.9274  val_f1=0.9491  val_auroc=0.9905  (no_improve=2)
# [ResNet18-scratch+SAM-1ch] epoch 42/90  tr_loss=0.3209  val_loss=0.5838  val_acc=0.7555  val_f1=0.8028  val_auroc=0.9854  (no_improve=3)
# [ResNet18-scratch+SAM-1ch] epoch 43/90  tr_loss=0.3207  val_loss=0.3341  val_acc=0.8777  val_f1=0.9106  val_auroc=0.9903  (no_improve=4)
# [ResNet18-scratch+SAM-1ch] epoch 44/90  tr_loss=0.3146  val_loss=0.3058  val_acc=0.8978  val_f1=0.9266  val_auroc=0.9903  (no_improve=5)
# [ResNet18-scratch+SAM-1ch] epoch 45/90  tr_loss=0.3139  val_loss=0.2267  val_acc=0.9408  val_f1=0.9592  val_auroc=0.9895  (no_improve=6)
# [ResNet18-scratch+SAM-1ch] epoch 46/90  tr_loss=0.3099  val_loss=0.2619  val_acc=0.9179  val_f1=0.9421  val_auroc=0.9886  (no_improve=7)
# [ResNet18-scratch+SAM-1ch] epoch 47/90  tr_loss=0.2909  val_loss=0.2187  val_acc=0.9475  val_f1=0.9637  val_auroc=0.9931  (no_improve=0)
# [ResNet18-scratch+SAM-1ch] epoch 48/90  tr_loss=0.2939  val_loss=0.4080  val_acc=0.8567  val_f1=0.8933  val_auroc=0.9920  (no_improve=1)
# [ResNet18-scratch+SAM-1ch] epoch 49/90  tr_loss=0.2984  val_loss=0.4092  val_acc=0.8491  val_f1=0.8871  val_auroc=0.9866  (no_improve=2)
# [ResNet18-scratch+SAM-1ch] epoch 50/90  tr_loss=0.2891  val_loss=0.4372  val_acc=0.8443  val_f1=0.8828  val_auroc=0.9934  (no_improve=0)
# [ResNet18-scratch+SAM-1ch] epoch 51/90  tr_loss=0.3020  val_loss=0.2783  val_acc=0.9093  val_f1=0.9353  val_auroc=0.9917  (no_improve=1)
# [ResNet18-scratch+SAM-1ch] epoch 52/90  tr_loss=0.2998  val_loss=0.3017  val_acc=0.8978  val_f1=0.9266  val_auroc=0.9915  (no_improve=2)
# [ResNet18-scratch+SAM-1ch] epoch 53/90  tr_loss=0.3004  val_loss=0.2654  val_acc=0.9160  val_f1=0.9404  val_auroc=0.9934  (no_improve=3)
# [ResNet18-scratch+SAM-1ch] epoch 54/90  tr_loss=0.2956  val_loss=0.2858  val_acc=0.8968  val_f1=0.9259  val_auroc=0.9919  (no_improve=4)
# [ResNet18-scratch+SAM-1ch] epoch 55/90  tr_loss=0.2861  val_loss=0.2870  val_acc=0.9160  val_f1=0.9405  val_auroc=0.9889  (no_improve=5)
# [ResNet18-scratch+SAM-1ch] epoch 56/90  tr_loss=0.2910  val_loss=0.2540  val_acc=0.9217  val_f1=0.9450  val_auroc=0.9913  (no_improve=6)
# [ResNet18-scratch+SAM-1ch] epoch 57/90  tr_loss=0.2812  val_loss=0.2534  val_acc=0.9331  val_f1=0.9530  val_auroc=0.9907  (no_improve=7)
# [ResNet18-scratch+SAM-1ch] epoch 58/90  tr_loss=0.2693  val_loss=0.2171  val_acc=0.9456  val_f1=0.9623  val_auroc=0.9932  (no_improve=8)
# [ResNet18-scratch+SAM-1ch] epoch 59/90  tr_loss=0.2684  val_loss=0.2505  val_acc=0.9303  val_f1=0.9510  val_auroc=0.9937  (no_improve=0)
# [ResNet18-scratch+SAM-1ch] epoch 60/90  tr_loss=0.2781  val_loss=0.2975  val_acc=0.9007  val_f1=0.9287  val_auroc=0.9934  (no_improve=1)
# [ResNet18-scratch+SAM-1ch] epoch 61/90  tr_loss=0.2731  val_loss=0.2577  val_acc=0.9217  val_f1=0.9446  val_auroc=0.9924  (no_improve=2)
# [ResNet18-scratch+SAM-1ch] epoch 62/90  tr_loss=0.2740  val_loss=0.3434  val_acc=0.8797  val_f1=0.9118  val_auroc=0.9924  (no_improve=3)
# [ResNet18-scratch+SAM-1ch] epoch 63/90  tr_loss=0.2524  val_loss=0.2521  val_acc=0.9293  val_f1=0.9504  val_auroc=0.9917  (no_improve=4)
# [ResNet18-scratch+SAM-1ch] epoch 64/90  tr_loss=0.2679  val_loss=0.2477  val_acc=0.9331  val_f1=0.9531  val_auroc=0.9942  (no_improve=0)
# [ResNet18-scratch+SAM-1ch] epoch 65/90  tr_loss=0.2550  val_loss=0.2563  val_acc=0.9255  val_f1=0.9476  val_auroc=0.9938  (no_improve=1)
# [ResNet18-scratch+SAM-1ch] epoch 66/90  tr_loss=0.2680  val_loss=0.1867  val_acc=0.9666  val_f1=0.9773  val_auroc=0.9950  (no_improve=0)
# [ResNet18-scratch+SAM-1ch] epoch 67/90  tr_loss=0.2470  val_loss=0.2568  val_acc=0.9303  val_f1=0.9510  val_auroc=0.9943  (no_improve=1)
# [ResNet18-scratch+SAM-1ch] epoch 68/90  tr_loss=0.2637  val_loss=0.2447  val_acc=0.9331  val_f1=0.9531  val_auroc=0.9949  (no_improve=2)
# [ResNet18-scratch+SAM-1ch] epoch 69/90  tr_loss=0.2538  val_loss=0.2555  val_acc=0.9312  val_f1=0.9518  val_auroc=0.9932  (no_improve=3)
# [ResNet18-scratch+SAM-1ch] epoch 70/90  tr_loss=0.2432  val_loss=0.2055  val_acc=0.9532  val_f1=0.9678  val_auroc=0.9938  (no_improve=4)
# [ResNet18-scratch+SAM-1ch] epoch 71/90  tr_loss=0.2495  val_loss=0.2444  val_acc=0.9351  val_f1=0.9545  val_auroc=0.9944  (no_improve=5)
# [ResNet18-scratch+SAM-1ch] epoch 72/90  tr_loss=0.2462  val_loss=0.2083  val_acc=0.9503  val_f1=0.9657  val_auroc=0.9946  (no_improve=6)
# [ResNet18-scratch+SAM-1ch] epoch 73/90  tr_loss=0.2559  val_loss=0.2238  val_acc=0.9465  val_f1=0.9629  val_auroc=0.9951  (no_improve=0)
# [ResNet18-scratch+SAM-1ch] epoch 74/90  tr_loss=0.2355  val_loss=0.2511  val_acc=0.9341  val_f1=0.9537  val_auroc=0.9943  (no_improve=1)
# [ResNet18-scratch+SAM-1ch] epoch 75/90  tr_loss=0.2492  val_loss=0.2075  val_acc=0.9551  val_f1=0.9691  val_auroc=0.9929  (no_improve=2)
# [ResNet18-scratch+SAM-1ch] epoch 76/90  tr_loss=0.2462  val_loss=0.2052  val_acc=0.9580  val_f1=0.9711  val_auroc=0.9956  (no_improve=0)
# [ResNet18-scratch+SAM-1ch] epoch 77/90  tr_loss=0.2404  val_loss=0.2274  val_acc=0.9446  val_f1=0.9615  val_auroc=0.9940  (no_improve=1)
# [ResNet18-scratch+SAM-1ch] epoch 78/90  tr_loss=0.2557  val_loss=0.2253  val_acc=0.9417  val_f1=0.9595  val_auroc=0.9941  (no_improve=2)
# [ResNet18-scratch+SAM-1ch] epoch 79/90  tr_loss=0.2421  val_loss=0.2114  val_acc=0.9522  val_f1=0.9671  val_auroc=0.9936  (no_improve=3)
# [ResNet18-scratch+SAM-1ch] epoch 80/90  tr_loss=0.2509  val_loss=0.2135  val_acc=0.9484  val_f1=0.9643  val_auroc=0.9948  (no_improve=4)
# [ResNet18-scratch+SAM-1ch] epoch 81/90  tr_loss=0.2374  val_loss=0.2105  val_acc=0.9494  val_f1=0.9651  val_auroc=0.9951  (no_improve=5)
# [ResNet18-scratch+SAM-1ch] epoch 82/90  tr_loss=0.2354  val_loss=0.2130  val_acc=0.9475  val_f1=0.9636  val_auroc=0.9952  (no_improve=6)
# [ResNet18-scratch+SAM-1ch] epoch 83/90  tr_loss=0.2312  val_loss=0.2181  val_acc=0.9456  val_f1=0.9622  val_auroc=0.9953  (no_improve=7)
# [ResNet18-scratch+SAM-1ch] epoch 84/90  tr_loss=0.2359  val_loss=0.2056  val_acc=0.9494  val_f1=0.9650  val_auroc=0.9950  (no_improve=8)
# [ResNet18-scratch+SAM-1ch] epoch 85/90  tr_loss=0.2347  val_loss=0.2125  val_acc=0.9465  val_f1=0.9629  val_auroc=0.9954  (no_improve=9)
# [ResNet18-scratch+SAM-1ch] epoch 86/90  tr_loss=0.2391  val_loss=0.2073  val_acc=0.9503  val_f1=0.9657  val_auroc=0.9953  (no_improve=10)
# [ResNet18-scratch+SAM-1ch] early stopping at epoch 86.
# [ResNet18-1ch+SAM @0.5] {'acc': 0.9359, 'precision': 0.9147, 'recall': 0.9897, 'f1': 0.9507, 'auroc': 0.9756, 'thr': 0.5}
# [ResNet18-1ch+SAM @Rec] {'acc': 0.9327, 'precision': 0.9104, 'recall': 0.9897, 'f1': 0.9484, 'auroc': 0.9756, 'thr': 0.4425}
# {'summary@0.5': {'acc': 0.9358974358974359,
#   'precision': 0.9146919431279621,
#   'recall': 0.9897435897435898,
#   'f1': 0.9507389162561576,
#   'auroc': 0.9756081525312295,
#   'thr': 0.5},
#  'summary@recall': {'acc': 0.9326923076923077,
#   'precision': 0.910377358490566,
#   'recall': 0.9897435897435898,
#   'f1': 0.9484029484029484,
#   'auroc': 0.9756081525312295,
#   'thr': 0.4425},
#  'threshold': 0.4425,
#  'time_sec': 20881.644665956497,
#  'params': 11171266}

# %%
vit = build_vit_scratch(
    img_size=224, in_chans=1, num_classes=2,   # <<< in_chans=1
    embed_dim=384, depth=12, heads=6, patch=16, mlp_ratio=4.0, drop=0.1
)
t0 = time.time()
vit_tr, vit_hist, vit_time = train_model(
    vit, train_loader, val_loader, DEVICE, arch="vit",
    epochs=120, base_lr=3e-4, weight_decay=0.1, label_smoothing=0.05,
    use_sam=True, sam_rho=0.10,    # a bit lower rho for ViT scratch tends to be stable
    use_cosine=True, warmup_epochs=5, min_lr_mult=0.01,
    monitor="va_auroc", patience=15, clip_grad_norm=1.0,
    class_weights=class_weights, llrd=False, head_lr_mult=1.0, use_amp=False,
    tag="ViT-scratch+SAM-1ch"
)
vit_time = time.time() - t0

plot_curve(vit_hist['tr_loss'], vit_hist['va_loss'], "ViT (1ch, SAM) — Loss")
plot_two_series(vit_hist['va_acc'], "Val Acc", vit_hist['va_f1'], "Val F1", "ViT (1ch, SAM) — Val")

va = evaluate(vit_tr, val_loader, DEVICE)
thr, *_ = choose_threshold_by_min_recall(va["targets"], va["probs"][:,1], scratch_sam.target_recall)
te = evaluate(vit_tr, test_loader, DEVICE)
sum_05   = summarize_at_threshold(te["targets"], te["probs"][:,1], 0.5)
sum_reca = summarize_at_threshold(te["targets"], te["probs"][:,1], thr)
print("[ViT-1ch+SAM @0.5]", {k: round(v,4) for k,v in sum_05.items()})
print("[ViT-1ch+SAM @Rec]", {k: round(v,4) for k,v in sum_reca.items()})
diag_plots("ViT (scratch+SAM, 1ch)", te["probs"], te["targets"], thr, auroc=te.get("auroc"))
add_result("ViT (scratch+SAM, 1ch)", vit_tr, sum_05, sum_reca, threshold=thr, time_sec=vit_time)
# Out:
# [ViT-scratch+SAM-1ch] epoch 01/120  tr_loss=0.6420  val_loss=0.6765  val_acc=0.6686  val_f1=0.7163  val_auroc=0.9122  (no_improve=0)
# [ViT-scratch+SAM-1ch] epoch 02/120  tr_loss=0.5623  val_loss=0.5658  val_acc=0.7641  val_f1=0.8164  val_auroc=0.9032  (no_improve=1)
# [ViT-scratch+SAM-1ch] epoch 03/120  tr_loss=0.5790  val_loss=0.6107  val_acc=0.7049  val_f1=0.7610  val_auroc=0.8987  (no_improve=2)
# [ViT-scratch+SAM-1ch] epoch 04/120  tr_loss=0.5593  val_loss=0.3840  val_acc=0.8663  val_f1=0.9036  val_auroc=0.9565  (no_improve=0)
# [ViT-scratch+SAM-1ch] epoch 05/120  tr_loss=0.5562  val_loss=0.3666  val_acc=0.8825  val_f1=0.9172  val_auroc=0.9525  (no_improve=1)
# [ViT-scratch+SAM-1ch] epoch 06/120  tr_loss=0.5148  val_loss=0.4205  val_acc=0.8300  val_f1=0.8727  val_auroc=0.9635  (no_improve=0)
# [ViT-scratch+SAM-1ch] epoch 07/120  tr_loss=0.5301  val_loss=0.4705  val_acc=0.8061  val_f1=0.8513  val_auroc=0.9648  (no_improve=0)
# [ViT-scratch+SAM-1ch] epoch 08/120  tr_loss=0.4880  val_loss=0.3196  val_acc=0.8883  val_f1=0.9219  val_auroc=0.9608  (no_improve=1)
# [ViT-scratch+SAM-1ch] epoch 09/120  tr_loss=0.4978  val_loss=0.3469  val_acc=0.8701  val_f1=0.9098  val_auroc=0.9430  (no_improve=2)
# [ViT-scratch+SAM-1ch] epoch 10/120  tr_loss=0.4820  val_loss=0.4011  val_acc=0.8500  val_f1=0.8897  val_auroc=0.9692  (no_improve=0)

# %%
# === Final comparison tables across all models in this notebook ===
# Builds two tables:
#   (A) Metrics at the threshold that achieves Recall >= 0.95 (from summary@recall)
#   (B) Metrics at fixed threshold = 0.5 (from summary@0.5)
# Requires: from src import result_registry ; each model added via add_result(name, ...)

import math, pandas as pd
from src import result_registry

TARGET_RECALL = 0.95  # what "recall >= 95%" means

if not result_registry:
    raise RuntimeError("result_registry is empty. Make sure you called add_result(...) after each model.")

def _extract_row(model_name: str, rec: dict, which: str):
    """
    which: 'summary@recall' or 'summary@0.5'
    Returns a flat row with common columns.
    """
    s = rec.get(which, {}) or {}
    # Prefer the per-summary 'thr' if present; else fall back to the top-level 'threshold'
    thr = s.get("thr", rec.get("threshold", float("nan")))
    row = {
        "model": model_name,
        "threshold": float(thr) if thr is not None and not isinstance(thr, str) else float("nan"),
        "acc": float(s.get("acc", float("nan"))),
        "precision": float(s.get("precision", float("nan"))),
        "recall": float(s.get("recall", float("nan"))),
        "f1": float(s.get("f1", float("nan"))),
        "auroc": float(s.get("auroc", float("nan"))),
        "params": rec.get("params", None),
        "time_sec": rec.get("time_sec", None),
    }
    return row

# Build both tables from the registry
rows_recall = []
rows_thr05 = []
for name, rec in result_registry.items():
    rows_recall.append(_extract_row(name, rec, "summary@recall"))
    rows_thr05.append(_extract_row(name, rec, "summary@0.5"))

df_recall = pd.DataFrame(rows_recall)
df_thr05  = pd.DataFrame(rows_thr05)

# Add convenience columns and formatting
def _format(df: pd.DataFrame, check_target=False) -> pd.DataFrame:
    df = df.copy()
    # Params in millions; training time in minutes
    if "params" in df:
        df["params (M)"] = df["params"].apply(lambda x: round(x/1e6, 2) if pd.notna(x) else math.nan)
    if "time_sec" in df:
        df["time (min)"] = df["time_sec"].apply(lambda x: round(x/60.0, 1) if pd.notna(x) else math.nan)

    # Human-friendly rounding
    if "threshold" in df: df["threshold"] = df["threshold"].round(3)
    for c in ["acc","precision","recall","f1","auroc"]:
        if c in df:
            df[c] = (df[c] * 100.0).round(2)  # show as %
    # Optional flag: did this row meet the target recall?
    if check_target and "recall" in df:
        df["meets_target(≥95%)"] = df["recall"].apply(lambda r: (pd.notna(r) and r >= TARGET_RECALL*100.0))
    # Reorder columns
    cols = ["model","threshold","acc","precision","recall","f1","auroc","params (M)","time (min)"]
    cols = [c for c in cols if c in df.columns]
    return df[cols]

# Sort by AUROC (desc) as a stable default; change to 'f1' if you prefer
df_recall = df_recall.sort_values(by="auroc", ascending=False).reset_index(drop=True)
df_thr05  = df_thr05.sort_values(by="auroc", ascending=False).reset_index(drop=True)

df_recall = _format(df_recall, check_target=True)
df_thr05  = _format(df_thr05,  check_target=False)

# Display
print("=== Table A — Metrics at threshold chosen to reach Recall ≥ 95% ===")
display(df_recall.style.format({
    "threshold": "{:.3f}",
    "acc": "{:.2f}%", "precision": "{:.2f}%", "recall": "{:.2f}%", "f1": "{:.2f}%", "auroc": "{:.2f}%",
    "params (M)": "{:.2f}", "time (min)": "{:.1f}"
}).set_properties(**{"text-align": "center"}))

print("\n=== Table B — Metrics at fixed threshold = 0.50 ===")
display(df_thr05.style.format({
    "threshold": "{:.3f}",
    "acc": "{:.2f}%", "precision": "{:.2f}%", "recall": "{:.2f}%", "f1": "{:.2f}%", "auroc": "{:.2f}%",
    "params (M)": "{:.2f}", "time (min)": "{:.1f}"
}).set_properties(**{"text-align": "center"}))

# (Optional) Save to CSV alongside the notebook
# df_recall.to_csv("results_table_recall>=95.csv", index=False)
# df_thr05.to_csv("results_table_thr=0.5.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[10], line 13
#      10 TARGET_RECALL = 0.95  # what "recall >= 95%" means
#      12 if not result_registry:
# ---> 13     raise RuntimeError("result_registry is empty. Make sure you called add_result(...) after each model.")
#      15 def _extract_row(model_name: str, rec: dict, which: str):
#      16     """
#      17     which: 'summary@recall' or 'summary@0.5'
#      18     Returns a flat row with common columns.
#      19     """
#
# RuntimeError: result_registry is empty. Make sure you called add_result(...) after each model.
