# %% [markdown]
# # Scratch baselines with SAM — CustomCNN, ResNet18, ViT (3‑channel)
# - Chest X-ray Pneumonia vs Normal (Kaggle) — **3-channel (RGB)** scratch baselines.
# - We convert grayscale to RGB with `T.Grayscale(3)` so all models receive 3 channels.
# - Same preprocessing across models; cosine LR with warmup; early stopping on AUROC.
# - Final metrics reported at **0.5** and at a **recall‑first** operating point (target recall = 0.95).

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
ZIP_PATH = "/content/drive/MyDrive/Data/chest-xray-pneumonia.zip"
DEST     = "/content/data"          # local fast disk
# !mkdir -p "$DEST"

# sanity check
# !ls -lh "$ZIP_PATH"
# Out:
# -rw------- 1 root root 2.3G Sep 28  2019 /content/drive/MyDrive/Data/chest-xray-pneumonia.zip

# %%
# -q: quiet, -o: overwrite if re-running
# !unzip -q -o "$ZIP_PATH" -d "$DEST"

# show what got extracted
# !find "$DEST" -maxdepth 2 -type d -print
# Out:
# /content/data
# /content/data/chest_xray
# /content/data/chest_xray/train
# /content/data/chest_xray/val
# /content/data/chest_xray/chest_xray
# /content/data/chest_xray/__MACOSX
# /content/data/chest_xray/test

# %%
# Clean imports + path setup
import sys, time, warnings
from pathlib import Path
try:
    from tqdm.auto import tqdm
except Exception:
    from tqdm import tqdm
from tqdm import TqdmWarning
warnings.filterwarnings("ignore", category=TqdmWarning)

# Resolve project root (directory containing `src/`)
proj_root = Path.cwd()
for _ in range(5):
    if (proj_root / "src").exists():
        break
    proj_root = proj_root.parent
sys.path.append(str(proj_root))

# Import project API
from src import (
    DataCfg, TrainCfg, set_seed, get_device, build_dataloaders,
    build_custom_cnn, build_resnet18, build_vit_scratch,
    train_model, evaluate, choose_threshold_by_min_recall, summarize_at_threshold,
    plot_curve, plot_two_series, diag_plots, add_result, result_registry
)
import numpy as np, pandas as pd, torch

set_seed(42)
DEVICE = get_device()
DEVICE
# Out:
# device(type='cuda')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# === Paths/config ===
DATASET_DIR = Path("/content/data/chest_xray")  # <--- EDIT THIS IF NEEDED

# Keep split identical across notebooks for fair comparison
data_cfg = DataCfg(
    dataset_dir=DATASET_DIR,
    image_size=224,
    batch_size=32,
    num_workers=4,          # 0 on macOS avoids "MallocStackLogging" noise
    pin_memory=True,
    use_stratified_val=True,
    val_ratio=0.20,         # use the same val split you used elsewhere
    gray_to_rgb=True,       # 3-CHANNEL: expand grayscale -> RGB
    compute_norm_stats=True,# compute mean/std from train set (3ch replicated)
    balance_sampler=True
)

train_loader, val_loader, test_loader, info = build_dataloaders(data_cfg, device=DEVICE)
print("Classes:", info["classes"])
print("Lens:", info["n_train"], info["n_val"], info["n_test"])
print("Train counts:", info["train_counts"])

# Class weights: when balance_sampler=True, set None to avoid double-correction
class_weights = None

# Sanity check: confirm 3-channel
xb, yb = next(iter(train_loader))
print("Batch shape:", tuple(xb.shape))  # expect (B, 3, 224, 224)
del xb, yb
# Out:
# Classes: ['NORMAL', 'PNEUMONIA']
# Lens: 4185 1047 624
# Train counts: [1079, 3106]
# Batch shape: (32, 3, 224, 224)

# %%
# Shared training cfg for scratch runs **with SAM**
scratch_sam = TrainCfg(
    epochs=100, patience=15, monitor="va_auroc",
    base_lr=3e-4, weight_decay=0.2,     # ViT defaults; CNN/ResNet override below
    clip_grad_norm=1.0, use_amp=False,
    use_sam=True, sam_rho=0.1,          # default; per-model overrides below
    use_cosine=True, warmup_epochs=3, min_lr_mult=0.01,
    target_recall=0.95,
    llrd=False, head_lr_mult=1.0
)

# %%
cfg = scratch_sam

cnn = build_custom_cnn(in_chans=3, num_classes=2, width=32, dropout=0.0)
t0 = time.time()
cnn_tr, cnn_hist, cnn_time = train_model(
    cnn, train_loader, val_loader, DEVICE, arch="custom_cnn",
    epochs=100, base_lr=0.1, weight_decay=1e-3, label_smoothing=0.0,
    use_sam=True, sam_rho=0.02,   # smaller rho works well for small CNNs
    use_cosine=True, warmup_epochs=3, min_lr_mult=0.01,
    monitor="va_auroc", patience=10, clip_grad_norm=1.0,
    class_weights=class_weights, llrd=False, head_lr_mult=1.0, use_amp=False,
    tag="CustomCNN-scratch-3ch+SAM"
)
plot_curve(cnn_hist['tr_loss'], cnn_hist['va_loss'], "CustomCNN (3ch, SAM) — Loss")
plot_two_series(cnn_hist['va_acc'], "Val Acc", cnn_hist['va_f1'], "Val F1", "CustomCNN (3ch, SAM) — Val")
va = evaluate(cnn_tr, val_loader, DEVICE)
thr, *_ = choose_threshold_by_min_recall(va["targets"], va["probs"][:,1], cfg.target_recall)
te = evaluate(cnn_tr, test_loader, DEVICE)
sum_05   = summarize_at_threshold(te["targets"], te["probs"][:,1], 0.5)
sum_reca = summarize_at_threshold(te["targets"], te["probs"][:,1], thr)
print("[CustomCNN-3ch+SAM @0.5]", {k: round(v,4) for k,v in sum_05.items()})
print("[CustomCNN-3ch+SAM @Rec]", {k: round(v,4) for k,v in sum_reca.items()})
diag_plots("CustomCNN (scratch+SAM, 3ch)", te["probs"], te["targets"], thr, auroc=te.get("auroc"))
add_result("CustomCNN (scratch+SAM, 3ch)", cnn_tr, sum_05, sum_reca, threshold=thr, time_sec=cnn_time)
# Out:
# [CustomCNN-scratch-3ch+SAM] epoch 01/100  tr_loss=0.4295  val_loss=0.4496  val_acc=0.8166  val_f1=0.8621  val_auroc=0.9438  (no_improve=0)
# [CustomCNN-scratch-3ch+SAM] epoch 02/100  tr_loss=0.4480  val_loss=0.8613  val_acc=0.6256  val_f1=0.6644  val_auroc=0.9402  (no_improve=1)
# [CustomCNN-scratch-3ch+SAM] epoch 03/100  tr_loss=0.4010  val_loss=0.3259  val_acc=0.8739  val_f1=0.9118  val_auroc=0.9363  (no_improve=2)
# [CustomCNN-scratch-3ch+SAM] epoch 04/100  tr_loss=0.3775  val_loss=0.3069  val_acc=0.8797  val_f1=0.9137  val_auroc=0.9465  (no_improve=0)
# [CustomCNN-scratch-3ch+SAM] epoch 05/100  tr_loss=0.3946  val_loss=0.2856  val_acc=0.8835  val_f1=0.9176  val_auroc=0.9469  (no_improve=0)
# [CustomCNN-scratch-3ch+SAM] epoch 06/100  tr_loss=0.3810  val_loss=0.2935  val_acc=0.8749  val_f1=0.9103  val_auroc=0.9552  (no_improve=0)
# [CustomCNN-scratch-3ch+SAM] epoch 07/100  tr_loss=0.3815  val_loss=0.2869  val_acc=0.8701  val_f1=0.9110  val_auroc=0.9325  (no_improve=1)
# [CustomCNN-scratch-3ch+SAM] epoch 08/100  tr_loss=0.3772  val_loss=0.2569  val_acc=0.8902  val_f1=0.9229  val_auroc=0.9557  (no_improve=0)
# [CustomCNN-scratch-3ch+SAM] epoch 09/100  tr_loss=0.3522  val_loss=0.9174  val_acc=0.6657  val_f1=0.7098  val_auroc=0.9660  (no_improve=0)
# [CustomCNN-scratch-3ch+SAM] epoch 10/100  tr_loss=0.3382  val_loss=0.4492  val_acc=0.8424  val_f1=0.8831  val_auroc=0.9459  (no_improve=1)
# [CustomCNN-scratch-3ch+SAM] epoch 11/100  tr_loss=0.3650  val_loss=0.2890  val_acc=0.8863  val_f1=0.9202  val_auroc=0.9524  (no_improve=2)
# [CustomCNN-scratch-3ch+SAM] epoch 12/100  tr_loss=0.3531  val_loss=0.3663  val_acc=0.8644  val_f1=0.9014  val_auroc=0.9551  (no_improve=3)
# [CustomCNN-scratch-3ch+SAM] epoch 13/100  tr_loss=0.3748  val_loss=0.3158  val_acc=0.8720  val_f1=0.9080  val_auroc=0.9475  (no_improve=4)
# [CustomCNN-scratch-3ch+SAM] epoch 14/100  tr_loss=0.3455  val_loss=0.3348  val_acc=0.8195  val_f1=0.8901  val_auroc=0.9442  (no_improve=5)
# [CustomCNN-scratch-3ch+SAM] epoch 15/100  tr_loss=0.3694  val_loss=0.8228  val_acc=0.7364  val_f1=0.7844  val_auroc=0.9573  (no_improve=6)
# [CustomCNN-scratch-3ch+SAM] epoch 16/100  tr_loss=0.3423  val_loss=0.5289  val_acc=0.8281  val_f1=0.8711  val_auroc=0.9453  (no_improve=7)
# [CustomCNN-scratch-3ch+SAM] epoch 17/100  tr_loss=0.3491  val_loss=0.3708  val_acc=0.8577  val_f1=0.8956  val_auroc=0.9577  (no_improve=8)
# [CustomCNN-scratch-3ch+SAM] epoch 18/100  tr_loss=0.3374  val_loss=0.2515  val_acc=0.8968  val_f1=0.9294  val_auroc=0.9551  (no_improve=9)
# [CustomCNN-scratch-3ch+SAM] epoch 19/100  tr_loss=0.3579  val_loss=0.2813  val_acc=0.8825  val_f1=0.9156  val_auroc=0.9666  (no_improve=0)
# [CustomCNN-scratch-3ch+SAM] epoch 20/100  tr_loss=0.3551  val_loss=0.2574  val_acc=0.8902  val_f1=0.9217  val_auroc=0.9613  (no_improve=1)
# [CustomCNN-scratch-3ch+SAM] epoch 21/100  tr_loss=0.3585  val_loss=0.5375  val_acc=0.8166  val_f1=0.8611  val_auroc=0.9454  (no_improve=2)
# [CustomCNN-scratch-3ch+SAM] epoch 22/100  tr_loss=0.3425  val_loss=0.6504  val_acc=0.7870  val_f1=0.8340  val_auroc=0.9590  (no_improve=3)
# [CustomCNN-scratch-3ch+SAM] epoch 23/100  tr_loss=0.3687  val_loss=0.8378  val_acc=0.7383  val_f1=0.7869  val_auroc=0.9614  (no_improve=4)
# [CustomCNN-scratch-3ch+SAM] epoch 24/100  tr_loss=0.3270  val_loss=0.4418  val_acc=0.8386  val_f1=0.8797  val_auroc=0.9465  (no_improve=5)
# [CustomCNN-scratch-3ch+SAM] epoch 25/100  tr_loss=0.3548  val_loss=0.2855  val_acc=0.8768  val_f1=0.9194  val_auroc=0.9378  (no_improve=6)
# [CustomCNN-scratch-3ch+SAM] epoch 26/100  tr_loss=0.3298  val_loss=0.3814  val_acc=0.8615  val_f1=0.8987  val_auroc=0.9513  (no_improve=7)
# [CustomCNN-scratch-3ch+SAM] epoch 27/100  tr_loss=0.3573  val_loss=0.3970  val_acc=0.8491  val_f1=0.8884  val_auroc=0.9605  (no_improve=8)
# [CustomCNN-scratch-3ch+SAM] epoch 28/100  tr_loss=0.3576  val_loss=0.4018  val_acc=0.8567  val_f1=0.8950  val_auroc=0.9517  (no_improve=9)
# [CustomCNN-scratch-3ch+SAM] epoch 29/100  tr_loss=0.3582  val_loss=0.3036  val_acc=0.8758  val_f1=0.9101  val_auroc=0.9705  (no_improve=0)
# [CustomCNN-scratch-3ch+SAM] epoch 30/100  tr_loss=0.3466  val_loss=0.6903  val_acc=0.7975  val_f1=0.8434  val_auroc=0.9602  (no_improve=1)
# [CustomCNN-scratch-3ch+SAM] epoch 31/100  tr_loss=0.3249  val_loss=0.3053  val_acc=0.8787  val_f1=0.9133  val_auroc=0.9459  (no_improve=2)
# [CustomCNN-scratch-3ch+SAM] epoch 32/100  tr_loss=0.3384  val_loss=0.2545  val_acc=0.8968  val_f1=0.9276  val_auroc=0.9551  (no_improve=3)
# [CustomCNN-scratch-3ch+SAM] epoch 33/100  tr_loss=0.3319  val_loss=0.2644  val_acc=0.8835  val_f1=0.9195  val_auroc=0.9407  (no_improve=4)
# [CustomCNN-scratch-3ch+SAM] epoch 34/100  tr_loss=0.3189  val_loss=0.3368  val_acc=0.8663  val_f1=0.9025  val_auroc=0.9660  (no_improve=5)
# [CustomCNN-scratch-3ch+SAM] epoch 35/100  tr_loss=0.3158  val_loss=0.2474  val_acc=0.8940  val_f1=0.9248  val_auroc=0.9621  (no_improve=6)
# [CustomCNN-scratch-3ch+SAM] epoch 36/100  tr_loss=0.3271  val_loss=0.2298  val_acc=0.9016  val_f1=0.9310  val_auroc=0.9721  (no_improve=0)
# [CustomCNN-scratch-3ch+SAM] epoch 37/100  tr_loss=0.3530  val_loss=0.4570  val_acc=0.8271  val_f1=0.8691  val_auroc=0.9701  (no_improve=1)
# [CustomCNN-scratch-3ch+SAM] epoch 38/100  tr_loss=0.3358  val_loss=0.2473  val_acc=0.8892  val_f1=0.9213  val_auroc=0.9708  (no_improve=2)
# [CustomCNN-scratch-3ch+SAM] epoch 39/100  tr_loss=0.3197  val_loss=0.3089  val_acc=0.8682  val_f1=0.9048  val_auroc=0.9639  (no_improve=3)
# [CustomCNN-scratch-3ch+SAM] epoch 40/100  tr_loss=0.3156  val_loss=0.7084  val_acc=0.7545  val_f1=0.8031  val_auroc=0.9400  (no_improve=4)
# [CustomCNN-scratch-3ch+SAM] epoch 41/100  tr_loss=0.3190  val_loss=0.3452  val_acc=0.8586  val_f1=0.8964  val_auroc=0.9634  (no_improve=5)
# [CustomCNN-scratch-3ch+SAM] epoch 42/100  tr_loss=0.3164  val_loss=0.5251  val_acc=0.8395  val_f1=0.8805  val_auroc=0.9635  (no_improve=6)
# [CustomCNN-scratch-3ch+SAM] epoch 43/100  tr_loss=0.3265  val_loss=0.4561  val_acc=0.8510  val_f1=0.8900  val_auroc=0.9668  (no_improve=7)
# [CustomCNN-scratch-3ch+SAM] epoch 44/100  tr_loss=0.3182  val_loss=0.3160  val_acc=0.8711  val_f1=0.9062  val_auroc=0.9579  (no_improve=8)
# [CustomCNN-scratch-3ch+SAM] epoch 45/100  tr_loss=0.3149  val_loss=0.3234  val_acc=0.8739  val_f1=0.9086  val_auroc=0.9598  (no_improve=9)
# [CustomCNN-scratch-3ch+SAM] epoch 46/100  tr_loss=0.3055  val_loss=0.4121  val_acc=0.8415  val_f1=0.8818  val_auroc=0.9637  (no_improve=10)
# [CustomCNN-scratch-3ch+SAM] early stopping at epoch 46.
# [CustomCNN-3ch+SAM @0.5] {'acc': 0.8301, 'precision': 0.8156, 'recall': 0.941, 'f1': 0.8738, 'auroc': np.float64(0.92), 'thr': 0.5}
# [CustomCNN-3ch+SAM @Rec] {'acc': 0.7804, 'precision': 0.7485, 'recall': 0.9769, 'f1': 0.8476, 'auroc': np.float64(0.92), 'thr': 0.3415}
# {'summary@0.5': {'acc': 0.8301282051282052,
#   'precision': 0.8155555555555556,
#   'recall': 0.941025641025641,
#   'f1': 0.8738095238095238,
#   'auroc': np.float64(0.9200306815691431),
#   'thr': 0.5},
#  'summary@recall': {'acc': 0.780448717948718,
#   'precision': 0.7485265225933202,
#   'recall': 0.9769230769230769,
#   'f1': 0.8476084538375973,
#   'auroc': np.float64(0.9200306815691431),
#   'thr': 0.3415},
#  'threshold': 0.3415,
#  'time_sec': 1867.9259197711945,
#  'params': 481698}

# %%
rn = build_resnet18(in_chans=3, num_classes=2, pretrained=False, conv_stem=False)
t0 = time.time()
rn_tr, rn_hist, rn_time = train_model(
    rn, train_loader, val_loader, DEVICE, arch="resnet18",
    epochs=90, base_lr=0.1, weight_decay=1e-3, label_smoothing=0.0,
    use_sam=True, sam_rho=0.05,  # robust rho for ResNet-18 with SAM
    use_cosine=True, warmup_epochs=3, min_lr_mult=0.01,
    monitor="va_auroc", patience=10, clip_grad_norm=1.0,
    class_weights=class_weights, llrd=False, head_lr_mult=1.0, use_amp=False,
    tag="ResNet18-scratch-3ch+SAM"
)
plot_curve(rn_hist['tr_loss'], rn_hist['va_loss'], "ResNet18 (3ch, SAM) — Loss")
plot_two_series(rn_hist['va_acc'], "Val Acc", rn_hist['va_f1'], "Val F1", "ResNet18 (3ch, SAM) — Val")
va = evaluate(rn_tr, val_loader, DEVICE)
thr, *_ = choose_threshold_by_min_recall(va["targets"], va["probs"][:,1], cfg.target_recall)
te = evaluate(rn_tr, test_loader, DEVICE)
sum_05   = summarize_at_threshold(te["targets"], te["probs"][:,1], 0.5)
sum_reca = summarize_at_threshold(te["targets"], te["probs"][:,1], thr)
print("[ResNet18-3ch+SAM @0.5]", {k: round(v,4) for k,v in sum_05.items()})
print("[ResNet18-3ch+SAM @Rec]", {k: round(v,4) for k,v in sum_reca.items()})
diag_plots("ResNet18 (scratch+SAM, 3ch)", te["probs"], te["targets"], thr, auroc=te.get("auroc"))
add_result("ResNet18 (scratch+SAM, 3ch)", rn_tr, sum_05, sum_reca, threshold=thr, time_sec=rn_time)
# Out:
# [ResNet18-scratch-3ch+SAM] epoch 01/90  tr_loss=0.5788  val_loss=0.3267  val_acc=0.8625  val_f1=0.9012  val_auroc=0.9515  (no_improve=0)
# [ResNet18-scratch-3ch+SAM] epoch 02/90  tr_loss=0.5936  val_loss=0.2859  val_acc=0.8749  val_f1=0.9113  val_auroc=0.9571  (no_improve=0)
# [ResNet18-scratch-3ch+SAM] epoch 03/90  tr_loss=0.5477  val_loss=0.4009  val_acc=0.8472  val_f1=0.8886  val_auroc=0.9350  (no_improve=1)
# [ResNet18-scratch-3ch+SAM] epoch 04/90  tr_loss=0.4318  val_loss=0.2552  val_acc=0.8863  val_f1=0.9208  val_auroc=0.9527  (no_improve=2)
# [ResNet18-scratch-3ch+SAM] epoch 05/90  tr_loss=0.3711  val_loss=0.4437  val_acc=0.7966  val_f1=0.8437  val_auroc=0.9424  (no_improve=3)
# [ResNet18-scratch-3ch+SAM] epoch 06/90  tr_loss=0.3397  val_loss=0.4056  val_acc=0.8434  val_f1=0.8832  val_auroc=0.9771  (no_improve=0)
# [ResNet18-scratch-3ch+SAM] epoch 07/90  tr_loss=0.3487  val_loss=0.8878  val_acc=0.7087  val_f1=0.7574  val_auroc=0.9393  (no_improve=1)
# [ResNet18-scratch-3ch+SAM] epoch 08/90  tr_loss=0.3388  val_loss=0.2346  val_acc=0.8892  val_f1=0.9216  val_auroc=0.9677  (no_improve=2)
# [ResNet18-scratch-3ch+SAM] epoch 09/90  tr_loss=0.3333  val_loss=0.2418  val_acc=0.8930  val_f1=0.9239  val_auroc=0.9748  (no_improve=3)
# [ResNet18-scratch-3ch+SAM] epoch 10/90  tr_loss=0.3444  val_loss=0.2106  val_acc=0.9160  val_f1=0.9421  val_auroc=0.9718  (no_improve=4)
# [ResNet18-scratch-3ch+SAM] epoch 11/90  tr_loss=0.3283  val_loss=0.6333  val_acc=0.7488  val_f1=0.7969  val_auroc=0.9830  (no_improve=0)
# [ResNet18-scratch-3ch+SAM] epoch 12/90  tr_loss=0.3312  val_loss=0.6167  val_acc=0.7927  val_f1=0.8382  val_auroc=0.9699  (no_improve=1)
# [ResNet18-scratch-3ch+SAM] epoch 13/90  tr_loss=0.3158  val_loss=0.1855  val_acc=0.9370  val_f1=0.9569  val_auroc=0.9767  (no_improve=2)
# [ResNet18-scratch-3ch+SAM] epoch 14/90  tr_loss=0.3247  val_loss=0.2833  val_acc=0.8625  val_f1=0.9138  val_auroc=0.9576  (no_improve=3)
# [ResNet18-scratch-3ch+SAM] epoch 15/90  tr_loss=0.3277  val_loss=0.2391  val_acc=0.9188  val_f1=0.9425  val_auroc=0.9875  (no_improve=0)
# [ResNet18-scratch-3ch+SAM] epoch 16/90  tr_loss=0.2949  val_loss=0.3059  val_acc=0.8768  val_f1=0.9102  val_auroc=0.9794  (no_improve=1)
# [ResNet18-scratch-3ch+SAM] epoch 17/90  tr_loss=0.3211  val_loss=0.2550  val_acc=0.8921  val_f1=0.9222  val_auroc=0.9780  (no_improve=2)
# [ResNet18-scratch-3ch+SAM] epoch 18/90  tr_loss=0.2957  val_loss=0.1894  val_acc=0.9236  val_f1=0.9464  val_auroc=0.9842  (no_improve=3)
# [ResNet18-scratch-3ch+SAM] epoch 19/90  tr_loss=0.3083  val_loss=0.3200  val_acc=0.8529  val_f1=0.8909  val_auroc=0.9838  (no_improve=4)
# [ResNet18-scratch-3ch+SAM] epoch 20/90  tr_loss=0.3141  val_loss=0.2503  val_acc=0.8940  val_f1=0.9240  val_auroc=0.9836  (no_improve=5)
# [ResNet18-scratch-3ch+SAM] epoch 21/90  tr_loss=0.2968  val_loss=0.2470  val_acc=0.8930  val_f1=0.9232  val_auroc=0.9825  (no_improve=6)
# [ResNet18-scratch-3ch+SAM] epoch 22/90  tr_loss=0.3022  val_loss=0.1884  val_acc=0.9198  val_f1=0.9445  val_auroc=0.9774  (no_improve=7)
# [ResNet18-scratch-3ch+SAM] epoch 23/90  tr_loss=0.2841  val_loss=0.1943  val_acc=0.9169  val_f1=0.9427  val_auroc=0.9711  (no_improve=8)
# [ResNet18-scratch-3ch+SAM] epoch 24/90  tr_loss=0.3106  val_loss=0.3854  val_acc=0.8434  val_f1=0.8832  val_auroc=0.9790  (no_improve=9)
# [ResNet18-scratch-3ch+SAM] epoch 25/90  tr_loss=0.3046  val_loss=0.3088  val_acc=0.8749  val_f1=0.9087  val_auroc=0.9803  (no_improve=10)
# [ResNet18-scratch-3ch+SAM] early stopping at epoch 25.
# [ResNet18-3ch+SAM @0.5] {'acc': 0.8798, 'precision': 0.8637, 'recall': 0.959, 'f1': 0.9089, 'auroc': np.float64(0.9312), 'thr': 0.5}
# [ResNet18-3ch+SAM @Rec] {'acc': 0.8429, 'precision': 0.8067, 'recall': 0.9846, 'f1': 0.8868, 'auroc': np.float64(0.9312), 'thr': 0.351}
# {'summary@0.5': {'acc': 0.8798076923076923,
#   'precision': 0.8637413394919169,
#   'recall': 0.958974358974359,
#   'f1': 0.9088699878493317,
#   'auroc': np.float64(0.9311856234933158),
#   'thr': 0.5},
#  'summary@recall': {'acc': 0.842948717948718,
#   'precision': 0.8067226890756303,
#   'recall': 0.9846153846153847,
#   'f1': 0.8868360277136259,
#   'auroc': np.float64(0.9311856234933158),
#   'thr': 0.35100000000000003},
#  'threshold': 0.35100000000000003,
#  'time_sec': 395.09565472602844,
#  'params': 11177538}

# %%
vit = build_vit_scratch(
    img_size=224, in_chans=3, num_classes=2,
    embed_dim=384, depth=12, heads=6, patch=16, mlp_ratio=4.0, drop=0.1
)
t0 = time.time()
vit_tr, vit_hist, vit_time = train_model(
    vit, train_loader, val_loader, DEVICE, arch="vit",
    epochs=120, base_lr=3e-4, weight_decay=0.3, label_smoothing=0.0,
    use_sam=True, sam_rho=0.2,    # per paper, SAM helps ViT a lot on small data
    use_cosine=True, warmup_epochs=5, min_lr_mult=0.01,
    monitor="va_auroc", patience=17, clip_grad_norm=1.0,
    class_weights=class_weights, llrd=False, head_lr_mult=1.0, use_amp=False,
    tag="ViT-scratch-3ch+SAM"
)
plot_curve(vit_hist['tr_loss'], vit_hist['va_loss'], "ViT (3ch, SAM) — Loss")
plot_two_series(vit_hist['va_acc'], "Val Acc", vit_hist['va_f1'], "Val F1", "ViT (3ch, SAM) — Val")

va = evaluate(vit_tr, val_loader, DEVICE)
thr, *_ = choose_threshold_by_min_recall(va["targets"], va["probs"][:,1], scratch_sam.target_recall)
te = evaluate(vit_tr, test_loader, DEVICE)
sum_05   = summarize_at_threshold(te["targets"], te["probs"][:,1], 0.5)
sum_reca = summarize_at_threshold(te["targets"], te["probs"][:,1], thr)
print("[ViT-3ch+SAM @0.5]", {k: round(v,4) for k,v in sum_05.items()})
print("[ViT-3ch+SAM @Rec]", {k: round(v,4) for k,v in sum_reca.items()})
diag_plots("ViT (scratch+SAM, 3ch)", te["probs"], te["targets"], thr, auroc=te.get("auroc"))
add_result("ViT (scratch+SAM, 3ch)", vit_tr, sum_05, sum_reca, threshold=thr, time_sec=vit_time)
# Out:
# [ViT-scratch-3ch+SAM] epoch 01/120  tr_loss=0.6714  val_loss=0.5207  val_acc=0.7373  val_f1=0.7918  val_auroc=0.9016  (no_improve=0)
# [ViT-scratch-3ch+SAM] epoch 02/120  tr_loss=0.5898  val_loss=0.4904  val_acc=0.7841  val_f1=0.8348  val_auroc=0.9224  (no_improve=0)
# [ViT-scratch-3ch+SAM] epoch 03/120  tr_loss=0.5685  val_loss=0.4738  val_acc=0.7736  val_f1=0.8261  val_auroc=0.9251  (no_improve=0)
# [ViT-scratch-3ch+SAM] epoch 04/120  tr_loss=0.5615  val_loss=0.5150  val_acc=0.7689  val_f1=0.8210  val_auroc=0.9303  (no_improve=0)
# [ViT-scratch-3ch+SAM] epoch 05/120  tr_loss=0.5242  val_loss=0.5137  val_acc=0.7708  val_f1=0.8217  val_auroc=0.9312  (no_improve=0)
# [ViT-scratch-3ch+SAM] epoch 06/120  tr_loss=0.5358  val_loss=0.5252  val_acc=0.7364  val_f1=0.7874  val_auroc=0.9417  (no_improve=0)
# [ViT-scratch-3ch+SAM] epoch 07/120  tr_loss=0.4997  val_loss=0.4945  val_acc=0.7689  val_f1=0.8228  val_auroc=0.9072  (no_improve=1)
# [ViT-scratch-3ch+SAM] epoch 08/120  tr_loss=0.5053  val_loss=0.3912  val_acc=0.8252  val_f1=0.8728  val_auroc=0.9280  (no_improve=2)
# [ViT-scratch-3ch+SAM] epoch 09/120  tr_loss=0.4928  val_loss=0.5328  val_acc=0.7641  val_f1=0.8139  val_auroc=0.9388  (no_improve=3)
# [ViT-scratch-3ch+SAM] epoch 10/120  tr_loss=0.4973  val_loss=0.3461  val_acc=0.8500  val_f1=0.8919  val_auroc=0.9369  (no_improve=4)
# [ViT-scratch-3ch+SAM] epoch 11/120  tr_loss=0.4681  val_loss=0.3513  val_acc=0.8548  val_f1=0.8953  val_auroc=0.9395  (no_improve=5)
# [ViT-scratch-3ch+SAM] epoch 12/120  tr_loss=0.4937  val_loss=0.4040  val_acc=0.8195  val_f1=0.8677  val_auroc=0.9180  (no_improve=6)
# [ViT-scratch-3ch+SAM] epoch 13/120  tr_loss=0.4725  val_loss=0.4799  val_acc=0.7736  val_f1=0.8233  val_auroc=0.9506  (no_improve=0)
# [ViT-scratch-3ch+SAM] epoch 14/120  tr_loss=0.4656  val_loss=0.4152  val_acc=0.8061  val_f1=0.8528  val_auroc=0.9442  (no_improve=1)
# [ViT-scratch-3ch+SAM] epoch 15/120  tr_loss=0.4671  val_loss=0.4652  val_acc=0.7937  val_f1=0.8430  val_auroc=0.9305  (no_improve=2)
# [ViT-scratch-3ch+SAM] epoch 16/120  tr_loss=0.4637  val_loss=0.3396  val_acc=0.8539  val_f1=0.8966  val_auroc=0.9366  (no_improve=3)
# [ViT-scratch-3ch+SAM] epoch 17/120  tr_loss=0.4520  val_loss=0.3709  val_acc=0.8567  val_f1=0.8950  val_auroc=0.9597  (no_improve=0)
# [ViT-scratch-3ch+SAM] epoch 18/120  tr_loss=0.4524  val_loss=0.3358  val_acc=0.8663  val_f1=0.9062  val_auroc=0.9351  (no_improve=1)
# [ViT-scratch-3ch+SAM] epoch 19/120  tr_loss=0.4457  val_loss=0.3334  val_acc=0.8806  val_f1=0.9143  val_auroc=0.9662  (no_improve=0)
# [ViT-scratch-3ch+SAM] epoch 20/120  tr_loss=0.4222  val_loss=0.3731  val_acc=0.8386  val_f1=0.8799  val_auroc=0.9615  (no_improve=1)
# [ViT-scratch-3ch+SAM] epoch 21/120  tr_loss=0.4351  val_loss=0.5173  val_acc=0.7221  val_f1=0.7714  val_auroc=0.9587  (no_improve=2)
# [ViT-scratch-3ch+SAM] epoch 22/120  tr_loss=0.4172  val_loss=0.3149  val_acc=0.8768  val_f1=0.9117  val_auroc=0.9576  (no_improve=3)
# [ViT-scratch-3ch+SAM] epoch 23/120  tr_loss=0.4230  val_loss=0.3500  val_acc=0.8434  val_f1=0.8840  val_auroc=0.9629  (no_improve=4)
# [ViT-scratch-3ch+SAM] epoch 24/120  tr_loss=0.4073  val_loss=0.2704  val_acc=0.8854  val_f1=0.9184  val_auroc=0.9671  (no_improve=0)
# [ViT-scratch-3ch+SAM] epoch 25/120  tr_loss=0.3928  val_loss=0.5396  val_acc=0.7173  val_f1=0.7658  val_auroc=0.9680  (no_improve=0)
# [ViT-scratch-3ch+SAM] epoch 26/120  tr_loss=0.3822  val_loss=0.3362  val_acc=0.8577  val_f1=0.8953  val_auroc=0.9689  (no_improve=0)
# [ViT-scratch-3ch+SAM] epoch 27/120  tr_loss=0.3697  val_loss=0.3398  val_acc=0.8558  val_f1=0.8931  val_auroc=0.9737  (no_improve=0)
# [ViT-scratch-3ch+SAM] epoch 28/120  tr_loss=0.3630  val_loss=0.3097  val_acc=0.8739  val_f1=0.9079  val_auroc=0.9766  (no_improve=0)
# [ViT-scratch-3ch+SAM] epoch 29/120  tr_loss=0.3850  val_loss=0.3430  val_acc=0.8510  val_f1=0.8894  val_auroc=0.9752  (no_improve=1)
# [ViT-scratch-3ch+SAM] epoch 30/120  tr_loss=0.3775  val_loss=0.2675  val_acc=0.8797  val_f1=0.9133  val_auroc=0.9703  (no_improve=2)
# [ViT-scratch-3ch+SAM] epoch 31/120  tr_loss=0.3398  val_loss=0.2350  val_acc=0.9035  val_f1=0.9317  val_auroc=0.9753  (no_improve=3)
# [ViT-scratch-3ch+SAM] epoch 32/120  tr_loss=0.3640  val_loss=0.2812  val_acc=0.8921  val_f1=0.9221  val_auroc=0.9790  (no_improve=0)
# [ViT-scratch-3ch+SAM] epoch 33/120  tr_loss=0.3640  val_loss=0.2248  val_acc=0.9150  val_f1=0.9398  val_auroc=0.9799  (no_improve=0)
# [ViT-scratch-3ch+SAM] epoch 34/120  tr_loss=0.3293  val_loss=0.2156  val_acc=0.9131  val_f1=0.9389  val_auroc=0.9772  (no_improve=1)
# [ViT-scratch-3ch+SAM] epoch 35/120  tr_loss=0.3408  val_loss=0.2507  val_acc=0.9074  val_f1=0.9339  val_auroc=0.9808  (no_improve=0)
# [ViT-scratch-3ch+SAM] epoch 36/120  tr_loss=0.3509  val_loss=0.1841  val_acc=0.9284  val_f1=0.9502  val_auroc=0.9810  (no_improve=0)
# [ViT-scratch-3ch+SAM] epoch 37/120  tr_loss=0.3423  val_loss=0.2119  val_acc=0.9131  val_f1=0.9388  val_auroc=0.9804  (no_improve=1)
# [ViT-scratch-3ch+SAM] epoch 38/120  tr_loss=0.3226  val_loss=0.2900  val_acc=0.8787  val_f1=0.9114  val_auroc=0.9833  (no_improve=0)
# [ViT-scratch-3ch+SAM] epoch 39/120  tr_loss=0.3401  val_loss=0.3531  val_acc=0.8567  val_f1=0.8936  val_auroc=0.9806  (no_improve=1)
# [ViT-scratch-3ch+SAM] epoch 40/120  tr_loss=0.3067  val_loss=0.2538  val_acc=0.8854  val_f1=0.9176  val_auroc=0.9765  (no_improve=2)
# [ViT-scratch-3ch+SAM] epoch 41/120  tr_loss=0.3297  val_loss=0.2622  val_acc=0.8883  val_f1=0.9196  val_auroc=0.9785  (no_improve=3)
# [ViT-scratch-3ch+SAM] epoch 42/120  tr_loss=0.3227  val_loss=0.2503  val_acc=0.9007  val_f1=0.9288  val_auroc=0.9812  (no_improve=4)
# [ViT-scratch-3ch+SAM] epoch 43/120  tr_loss=0.2985  val_loss=0.2197  val_acc=0.9074  val_f1=0.9341  val_auroc=0.9792  (no_improve=5)
# [ViT-scratch-3ch+SAM] epoch 44/120  tr_loss=0.3059  val_loss=0.2470  val_acc=0.8988  val_f1=0.9274  val_auroc=0.9786  (no_improve=6)
# [ViT-scratch-3ch+SAM] epoch 45/120  tr_loss=0.3116  val_loss=0.3211  val_acc=0.8682  val_f1=0.9031  val_auroc=0.9796  (no_improve=7)
# [ViT-scratch-3ch+SAM] epoch 46/120  tr_loss=0.3208  val_loss=0.3308  val_acc=0.8634  val_f1=0.8994  val_auroc=0.9807  (no_improve=8)
# [ViT-scratch-3ch+SAM] epoch 47/120  tr_loss=0.3054  val_loss=0.1987  val_acc=0.9140  val_f1=0.9394  val_auroc=0.9801  (no_improve=9)
# [ViT-scratch-3ch+SAM] epoch 48/120  tr_loss=0.3033  val_loss=0.2438  val_acc=0.8959  val_f1=0.9253  val_auroc=0.9745  (no_improve=10)
# [ViT-scratch-3ch+SAM] epoch 49/120  tr_loss=0.2984  val_loss=0.2195  val_acc=0.9160  val_f1=0.9409  val_auroc=0.9761  (no_improve=11)
# [ViT-scratch-3ch+SAM] epoch 50/120  tr_loss=0.2952  val_loss=0.2177  val_acc=0.9131  val_f1=0.9385  val_auroc=0.9813  (no_improve=12)
# [ViT-scratch-3ch+SAM] epoch 51/120  tr_loss=0.2814  val_loss=0.2775  val_acc=0.8787  val_f1=0.9117  val_auroc=0.9792  (no_improve=13)
# [ViT-scratch-3ch+SAM] epoch 52/120  tr_loss=0.2983  val_loss=0.1969  val_acc=0.9207  val_f1=0.9442  val_auroc=0.9839  (no_improve=0)
# [ViT-scratch-3ch+SAM] epoch 53/120  tr_loss=0.3103  val_loss=0.2243  val_acc=0.9035  val_f1=0.9311  val_auroc=0.9833  (no_improve=1)
# [ViT-scratch-3ch+SAM] epoch 54/120  tr_loss=0.2714  val_loss=0.1796  val_acc=0.9265  val_f1=0.9489  val_auroc=0.9801  (no_improve=2)
# [ViT-scratch-3ch+SAM] epoch 55/120  tr_loss=0.2891  val_loss=0.2210  val_acc=0.9093  val_f1=0.9353  val_auroc=0.9837  (no_improve=3)
# [ViT-scratch-3ch+SAM] epoch 56/120  tr_loss=0.2709  val_loss=0.1975  val_acc=0.9207  val_f1=0.9445  val_auroc=0.9781  (no_improve=4)
# [ViT-scratch-3ch+SAM] epoch 57/120  tr_loss=0.2852  val_loss=0.2256  val_acc=0.9035  val_f1=0.9312  val_auroc=0.9789  (no_improve=5)
# [ViT-scratch-3ch+SAM] epoch 58/120  tr_loss=0.2870  val_loss=0.2698  val_acc=0.8777  val_f1=0.9109  val_auroc=0.9795  (no_improve=6)
# [ViT-scratch-3ch+SAM] epoch 59/120  tr_loss=0.2919  val_loss=0.2675  val_acc=0.8883  val_f1=0.9194  val_auroc=0.9808  (no_improve=7)
# [ViT-scratch-3ch+SAM] epoch 60/120  tr_loss=0.2744  val_loss=0.1779  val_acc=0.9331  val_f1=0.9535  val_auroc=0.9810  (no_improve=8)
# [ViT-scratch-3ch+SAM] epoch 61/120  tr_loss=0.2889  val_loss=0.1907  val_acc=0.9245  val_f1=0.9474  val_auroc=0.9803  (no_improve=9)
# [ViT-scratch-3ch+SAM] epoch 62/120  tr_loss=0.2819  val_loss=0.1800  val_acc=0.9331  val_f1=0.9534  val_auroc=0.9816  (no_improve=10)
# [ViT-scratch-3ch+SAM] epoch 62/120  tr_loss=0.2819  val_loss=0.1800  val_acc=0.9331  val_f1=0.9534  val_auroc=0.9816  (no_improve=10)
# [ViT-scratch-3ch+SAM] epoch 63/120  tr_loss=0.2800  val_loss=0.2121  val_acc=0.9064  val_f1=0.9333  val_auroc=0.9810  (no_improve=11)
# [ViT-scratch-3ch+SAM] epoch 63/120  tr_loss=0.2800  val_loss=0.2121  val_acc=0.9064  val_f1=0.9333  val_auroc=0.9810  (no_improve=11)
# [ViT-scratch-3ch+SAM] epoch 64/120  tr_loss=0.2743  val_loss=0.1980  val_acc=0.9131  val_f1=0.9386  val_auroc=0.9802  (no_improve=12)
# [ViT-scratch-3ch+SAM] epoch 64/120  tr_loss=0.2743  val_loss=0.1980  val_acc=0.9131  val_f1=0.9386  val_auroc=0.9802  (no_improve=12)
# [ViT-scratch-3ch+SAM] epoch 65/120  tr_loss=0.2710  val_loss=0.2129  val_acc=0.9188  val_f1=0.9425  val_auroc=0.9810  (no_improve=13)
# [ViT-scratch-3ch+SAM] epoch 65/120  tr_loss=0.2710  val_loss=0.2129  val_acc=0.9188  val_f1=0.9425  val_auroc=0.9810  (no_improve=13)
# [ViT-scratch-3ch+SAM] epoch 66/120  tr_loss=0.2696  val_loss=0.2388  val_acc=0.9035  val_f1=0.9311  val_auroc=0.9816  (no_improve=14)
# [ViT-scratch-3ch+SAM] epoch 66/120  tr_loss=0.2696  val_loss=0.2388  val_acc=0.9035  val_f1=0.9311  val_auroc=0.9816  (no_improve=14)
# [ViT-scratch-3ch+SAM] epoch 67/120  tr_loss=0.2687  val_loss=0.2393  val_acc=0.9035  val_f1=0.9309  val_auroc=0.9839  (no_improve=15)
# [ViT-scratch-3ch+SAM] epoch 67/120  tr_loss=0.2687  val_loss=0.2393  val_acc=0.9035  val_f1=0.9309  val_auroc=0.9839  (no_improve=15)
# [ViT-scratch-3ch+SAM] epoch 68/120  tr_loss=0.2550  val_loss=0.2715  val_acc=0.8873  val_f1=0.9183  val_auroc=0.9832  (no_improve=16)
# [ViT-scratch-3ch+SAM] epoch 68/120  tr_loss=0.2550  val_loss=0.2715  val_acc=0.8873  val_f1=0.9183  val_auroc=0.9832  (no_improve=16)
# [ViT-scratch-3ch+SAM] epoch 69/120  tr_loss=0.2800  val_loss=0.2393  val_acc=0.8988  val_f1=0.9274  val_auroc=0.9848  (no_improve=0)
# [ViT-scratch-3ch+SAM] epoch 69/120  tr_loss=0.2800  val_loss=0.2393  val_acc=0.8988  val_f1=0.9274  val_auroc=0.9848  (no_improve=0)
# [ViT-scratch-3ch+SAM] epoch 70/120  tr_loss=0.2750  val_loss=0.2306  val_acc=0.9112  val_f1=0.9368  val_auroc=0.9834  (no_improve=1)
# [ViT-scratch-3ch+SAM] epoch 70/120  tr_loss=0.2750  val_loss=0.2306  val_acc=0.9112  val_f1=0.9368  val_auroc=0.9834  (no_improve=1)
# [ViT-scratch-3ch+SAM] epoch 71/120  tr_loss=0.2715  val_loss=0.1967  val_acc=0.9169  val_f1=0.9416  val_auroc=0.9806  (no_improve=2)
# [ViT-scratch-3ch+SAM] epoch 71/120  tr_loss=0.2715  val_loss=0.1967  val_acc=0.9169  val_f1=0.9416  val_auroc=0.9806  (no_improve=2)
# [ViT-scratch-3ch+SAM] epoch 72/120  tr_loss=0.2558  val_loss=0.1845  val_acc=0.9207  val_f1=0.9442  val_auroc=0.9849  (no_improve=0)
# [ViT-scratch-3ch+SAM] epoch 72/120  tr_loss=0.2558  val_loss=0.1845  val_acc=0.9207  val_f1=0.9442  val_auroc=0.9849  (no_improve=0)
# [ViT-scratch-3ch+SAM] epoch 73/120  tr_loss=0.2580  val_loss=0.1867  val_acc=0.9217  val_f1=0.9449  val_auroc=0.9833  (no_improve=1)
# [ViT-scratch-3ch+SAM] epoch 73/120  tr_loss=0.2580  val_loss=0.1867  val_acc=0.9217  val_f1=0.9449  val_auroc=0.9833  (no_improve=1)
# [ViT-scratch-3ch+SAM] epoch 74/120  tr_loss=0.2537  val_loss=0.1595  val_acc=0.9331  val_f1=0.9536  val_auroc=0.9835  (no_improve=2)
# [ViT-scratch-3ch+SAM] epoch 74/120  tr_loss=0.2537  val_loss=0.1595  val_acc=0.9331  val_f1=0.9536  val_auroc=0.9835  (no_improve=2)
# [ViT-scratch-3ch+SAM] epoch 75/120  tr_loss=0.2672  val_loss=0.1889  val_acc=0.9217  val_f1=0.9450  val_auroc=0.9819  (no_improve=3)
# [ViT-scratch-3ch+SAM] epoch 75/120  tr_loss=0.2672  val_loss=0.1889  val_acc=0.9217  val_f1=0.9450  val_auroc=0.9819  (no_improve=3)
# [ViT-scratch-3ch+SAM] epoch 76/120  tr_loss=0.2629  val_loss=0.1854  val_acc=0.9274  val_f1=0.9492  val_auroc=0.9818  (no_improve=4)
# [ViT-scratch-3ch+SAM] epoch 76/120  tr_loss=0.2629  val_loss=0.1854  val_acc=0.9274  val_f1=0.9492  val_auroc=0.9818  (no_improve=4)
# [ViT-scratch-3ch+SAM] epoch 77/120  tr_loss=0.2513  val_loss=0.2006  val_acc=0.9112  val_f1=0.9371  val_auroc=0.9818  (no_improve=5)
# [ViT-scratch-3ch+SAM] epoch 77/120  tr_loss=0.2513  val_loss=0.2006  val_acc=0.9112  val_f1=0.9371  val_auroc=0.9818  (no_improve=5)
# [ViT-scratch-3ch+SAM] epoch 78/120  tr_loss=0.2547  val_loss=0.2525  val_acc=0.8940  val_f1=0.9237  val_auroc=0.9834  (no_improve=6)
# [ViT-scratch-3ch+SAM] epoch 78/120  tr_loss=0.2547  val_loss=0.2525  val_acc=0.8940  val_f1=0.9237  val_auroc=0.9834  (no_improve=6)
# [ViT-scratch-3ch+SAM] epoch 79/120  tr_loss=0.2583  val_loss=0.2312  val_acc=0.8997  val_f1=0.9281  val_auroc=0.9824  (no_improve=7)
# [ViT-scratch-3ch+SAM] epoch 79/120  tr_loss=0.2583  val_loss=0.2312  val_acc=0.8997  val_f1=0.9281  val_auroc=0.9824  (no_improve=7)
# [ViT-scratch-3ch+SAM] epoch 80/120  tr_loss=0.2448  val_loss=0.2290  val_acc=0.9016  val_f1=0.9296  val_auroc=0.9834  (no_improve=8)
# [ViT-scratch-3ch+SAM] epoch 80/120  tr_loss=0.2448  val_loss=0.2290  val_acc=0.9016  val_f1=0.9296  val_auroc=0.9834  (no_improve=8)
# [ViT-scratch-3ch+SAM] epoch 81/120  tr_loss=0.2479  val_loss=0.2591  val_acc=0.8902  val_f1=0.9206  val_auroc=0.9830  (no_improve=9)
# [ViT-scratch-3ch+SAM] epoch 81/120  tr_loss=0.2479  val_loss=0.2591  val_acc=0.8902  val_f1=0.9206  val_auroc=0.9830  (no_improve=9)
# [ViT-scratch-3ch+SAM] epoch 82/120  tr_loss=0.2420  val_loss=0.1894  val_acc=0.9265  val_f1=0.9483  val_auroc=0.9844  (no_improve=10)
# [ViT-scratch-3ch+SAM] epoch 82/120  tr_loss=0.2420  val_loss=0.1894  val_acc=0.9265  val_f1=0.9483  val_auroc=0.9844  (no_improve=10)
# [ViT-scratch-3ch+SAM] epoch 83/120  tr_loss=0.2536  val_loss=0.1844  val_acc=0.9265  val_f1=0.9484  val_auroc=0.9846  (no_improve=11)
# [ViT-scratch-3ch+SAM] epoch 83/120  tr_loss=0.2536  val_loss=0.1844  val_acc=0.9265  val_f1=0.9484  val_auroc=0.9846  (no_improve=11)
# [ViT-scratch-3ch+SAM] epoch 84/120  tr_loss=0.2350  val_loss=0.1816  val_acc=0.9303  val_f1=0.9513  val_auroc=0.9836  (no_improve=12)
# [ViT-scratch-3ch+SAM] epoch 84/120  tr_loss=0.2350  val_loss=0.1816  val_acc=0.9303  val_f1=0.9513  val_auroc=0.9836  (no_improve=12)
# [ViT-scratch-3ch+SAM] epoch 85/120  tr_loss=0.2474  val_loss=0.2083  val_acc=0.9188  val_f1=0.9427  val_auroc=0.9842  (no_improve=13)
# [ViT-scratch-3ch+SAM] epoch 85/120  tr_loss=0.2474  val_loss=0.2083  val_acc=0.9188  val_f1=0.9427  val_auroc=0.9842  (no_improve=13)
# [ViT-scratch-3ch+SAM] epoch 86/120  tr_loss=0.2231  val_loss=0.1865  val_acc=0.9265  val_f1=0.9485  val_auroc=0.9819  (no_improve=14)
# [ViT-scratch-3ch+SAM] epoch 86/120  tr_loss=0.2231  val_loss=0.1865  val_acc=0.9265  val_f1=0.9485  val_auroc=0.9819  (no_improve=14)
# [ViT-scratch-3ch+SAM] epoch 87/120  tr_loss=0.2265  val_loss=0.1851  val_acc=0.9226  val_f1=0.9456  val_auroc=0.9829  (no_improve=15)
# [ViT-scratch-3ch+SAM] epoch 87/120  tr_loss=0.2265  val_loss=0.1851  val_acc=0.9226  val_f1=0.9456  val_auroc=0.9829  (no_improve=15)
# [ViT-scratch-3ch+SAM] epoch 88/120  tr_loss=0.2434  val_loss=0.2484  val_acc=0.8959  val_f1=0.9251  val_auroc=0.9863  (no_improve=0)
# [ViT-scratch-3ch+SAM] epoch 88/120  tr_loss=0.2434  val_loss=0.2484  val_acc=0.8959  val_f1=0.9251  val_auroc=0.9863  (no_improve=0)
# [ViT-scratch-3ch+SAM] epoch 89/120  tr_loss=0.2455  val_loss=0.2186  val_acc=0.9160  val_f1=0.9405  val_auroc=0.9856  (no_improve=1)
# [ViT-scratch-3ch+SAM] epoch 89/120  tr_loss=0.2455  val_loss=0.2186  val_acc=0.9160  val_f1=0.9405  val_auroc=0.9856  (no_improve=1)
# [ViT-scratch-3ch+SAM] epoch 90/120  tr_loss=0.2347  val_loss=0.1980  val_acc=0.9150  val_f1=0.9398  val_auroc=0.9850  (no_improve=2)
# [ViT-scratch-3ch+SAM] epoch 90/120  tr_loss=0.2347  val_loss=0.1980  val_acc=0.9150  val_f1=0.9398  val_auroc=0.9850  (no_improve=2)
# [ViT-scratch-3ch+SAM] epoch 91/120  tr_loss=0.2464  val_loss=0.1656  val_acc=0.9341  val_f1=0.9541  val_auroc=0.9835  (no_improve=3)
# [ViT-scratch-3ch+SAM] epoch 91/120  tr_loss=0.2464  val_loss=0.1656  val_acc=0.9341  val_f1=0.9541  val_auroc=0.9835  (no_improve=3)
# [ViT-scratch-3ch+SAM] epoch 92/120  tr_loss=0.2552  val_loss=0.1831  val_acc=0.9284  val_f1=0.9497  val_auroc=0.9838  (no_improve=4)
# [ViT-scratch-3ch+SAM] epoch 92/120  tr_loss=0.2552  val_loss=0.1831  val_acc=0.9284  val_f1=0.9497  val_auroc=0.9838  (no_improve=4)
# [ViT-scratch-3ch+SAM] epoch 93/120  tr_loss=0.2428  val_loss=0.1866  val_acc=0.9217  val_f1=0.9448  val_auroc=0.9853  (no_improve=5)
# [ViT-scratch-3ch+SAM] epoch 93/120  tr_loss=0.2428  val_loss=0.1866  val_acc=0.9217  val_f1=0.9448  val_auroc=0.9853  (no_improve=5)
# [ViT-scratch-3ch+SAM] epoch 94/120  tr_loss=0.2463  val_loss=0.1705  val_acc=0.9293  val_f1=0.9506  val_auroc=0.9840  (no_improve=6)
# [ViT-scratch-3ch+SAM] epoch 94/120  tr_loss=0.2463  val_loss=0.1705  val_acc=0.9293  val_f1=0.9506  val_auroc=0.9840  (no_improve=6)
# [ViT-scratch-3ch+SAM] epoch 95/120  tr_loss=0.2165  val_loss=0.1910  val_acc=0.9179  val_f1=0.9420  val_auroc=0.9856  (no_improve=7)
# [ViT-scratch-3ch+SAM] epoch 95/120  tr_loss=0.2165  val_loss=0.1910  val_acc=0.9179  val_f1=0.9420  val_auroc=0.9856  (no_improve=7)
# [ViT-scratch-3ch+SAM] epoch 96/120  tr_loss=0.2375  val_loss=0.1832  val_acc=0.9245  val_f1=0.9469  val_auroc=0.9848  (no_improve=8)
# [ViT-scratch-3ch+SAM] epoch 96/120  tr_loss=0.2375  val_loss=0.1832  val_acc=0.9245  val_f1=0.9469  val_auroc=0.9848  (no_improve=8)
# [ViT-scratch-3ch+SAM] epoch 97/120  tr_loss=0.2288  val_loss=0.1807  val_acc=0.9245  val_f1=0.9471  val_auroc=0.9835  (no_improve=9)
# [ViT-scratch-3ch+SAM] epoch 97/120  tr_loss=0.2288  val_loss=0.1807  val_acc=0.9245  val_f1=0.9471  val_auroc=0.9835  (no_improve=9)
# [ViT-scratch-3ch+SAM] epoch 98/120  tr_loss=0.2327  val_loss=0.1799  val_acc=0.9265  val_f1=0.9484  val_auroc=0.9842  (no_improve=10)
# [ViT-scratch-3ch+SAM] epoch 98/120  tr_loss=0.2327  val_loss=0.1799  val_acc=0.9265  val_f1=0.9484  val_auroc=0.9842  (no_improve=10)
# [ViT-scratch-3ch+SAM] epoch 99/120  tr_loss=0.2427  val_loss=0.1671  val_acc=0.9360  val_f1=0.9554  val_auroc=0.9844  (no_improve=11)
# [ViT-scratch-3ch+SAM] epoch 99/120  tr_loss=0.2427  val_loss=0.1671  val_acc=0.9360  val_f1=0.9554  val_auroc=0.9844  (no_improve=11)
# [ViT-scratch-3ch+SAM] epoch 100/120  tr_loss=0.2348  val_loss=0.1842  val_acc=0.9255  val_f1=0.9477  val_auroc=0.9839  (no_improve=12)
# [ViT-scratch-3ch+SAM] epoch 100/120  tr_loss=0.2348  val_loss=0.1842  val_acc=0.9255  val_f1=0.9477  val_auroc=0.9839  (no_improve=12)
# [ViT-scratch-3ch+SAM] epoch 101/120  tr_loss=0.2410  val_loss=0.1770  val_acc=0.9284  val_f1=0.9498  val_auroc=0.9846  (no_improve=13)
# [ViT-scratch-3ch+SAM] epoch 101/120  tr_loss=0.2410  val_loss=0.1770  val_acc=0.9284  val_f1=0.9498  val_auroc=0.9846  (no_improve=13)
# [ViT-scratch-3ch+SAM] epoch 102/120  tr_loss=0.2393  val_loss=0.1679  val_acc=0.9341  val_f1=0.9540  val_auroc=0.9843  (no_improve=14)
# [ViT-scratch-3ch+SAM] epoch 102/120  tr_loss=0.2393  val_loss=0.1679  val_acc=0.9341  val_f1=0.9540  val_auroc=0.9843  (no_improve=14)
# [ViT-scratch-3ch+SAM] epoch 103/120  tr_loss=0.2275  val_loss=0.1854  val_acc=0.9207  val_f1=0.9441  val_auroc=0.9849  (no_improve=15)
# [ViT-scratch-3ch+SAM] epoch 103/120  tr_loss=0.2275  val_loss=0.1854  val_acc=0.9207  val_f1=0.9441  val_auroc=0.9849  (no_improve=15)
# [ViT-scratch-3ch+SAM] epoch 104/120  tr_loss=0.2400  val_loss=0.2003  val_acc=0.9150  val_f1=0.9398  val_auroc=0.9859  (no_improve=16)
# [ViT-scratch-3ch+SAM] epoch 104/120  tr_loss=0.2400  val_loss=0.2003  val_acc=0.9150  val_f1=0.9398  val_auroc=0.9859  (no_improve=16)
# [ViT-scratch-3ch+SAM] epoch 105/120  tr_loss=0.2317  val_loss=0.1999  val_acc=0.9179  val_f1=0.9418  val_auroc=0.9856  (no_improve=17)
# [ViT-scratch-3ch+SAM] early stopping at epoch 105.
# [ViT-scratch-3ch+SAM] epoch 105/120  tr_loss=0.2317  val_loss=0.1999  val_acc=0.9179  val_f1=0.9418  val_auroc=0.9856  (no_improve=17)
# [ViT-scratch-3ch+SAM] early stopping at epoch 105.
# [ViT-3ch+SAM @0.5] {'acc': 0.8846, 'precision': 0.9036, 'recall': 0.9128, 'f1': 0.9082, 'auroc': np.float64(0.943), 'thr': 0.5}
# [ViT-3ch+SAM @Rec] {'acc': 0.8622, 'precision': 0.8304, 'recall': 0.9795, 'f1': 0.8988, 'auroc': np.float64(0.943), 'thr': 0.135}
# [ViT-3ch+SAM @0.5] {'acc': 0.8846, 'precision': 0.9036, 'recall': 0.9128, 'f1': 0.9082, 'auroc': np.float64(0.943), 'thr': 0.5}
# [ViT-3ch+SAM @Rec] {'acc': 0.8622, 'precision': 0.8304, 'recall': 0.9795, 'f1': 0.8988, 'auroc': np.float64(0.943), 'thr': 0.135}
# {'summary@0.5': {'acc': 0.8846153846153846,
#   'precision': 0.9035532994923858,
#   'recall': 0.9128205128205128,
#   'f1': 0.9081632653061225,
#   'auroc': np.float64(0.9429761122068815),
#   'thr': 0.5},
#  'summary@recall': {'acc': 0.8621794871794872,
#   'precision': 0.8304347826086956,
#   'recall': 0.9794871794871794,
#   'f1': 0.8988235294117647,
#   'auroc': np.float64(0.9429761122068815),
#   'thr': 0.135},
#  'threshold': 0.135,
#  'time_sec': 4365.559239149094,
#  'params': 21666434}
# {'summary@0.5': {'acc': 0.8846153846153846,
#   'precision': 0.9035532994923858,
#   'recall': 0.9128205128205128,
#   'f1': 0.9081632653061225,
#   'auroc': np.float64(0.9429761122068815),
#   'thr': 0.5},
#  'summary@recall': {'acc': 0.8621794871794872,
#   'precision': 0.8304347826086956,
#   'recall': 0.9794871794871794,
#   'f1': 0.8988235294117647,
#   'auroc': np.float64(0.9429761122068815),
#   'thr': 0.135},
#  'threshold': 0.135,
#  'time_sec': 4365.559239149094,
#  'params': 21666434}

# %%
# === Final comparison tables across all models in this notebook ===
# Builds two tables:
#   (A) Metrics at the threshold that achieves Recall >= 0.95 (from summary@recall)
#   (B) Metrics at fixed threshold = 0.5 (from summary@0.5)
# Requires: from src import result_registry ; each model added via add_result(name, ...)

import math, pandas as pd
from src import result_registry

TARGET_RECALL = 0.95  # what "recall >= 95%" means

if not result_registry:
    raise RuntimeError("result_registry is empty. Make sure you called add_result(...) after each model.")

def _extract_row(model_name: str, rec: dict, which: str):
    """
    which: 'summary@recall' or 'summary@0.5'
    Returns a flat row with common columns.
    """
    s = rec.get(which, {}) or {}
    # Prefer the per-summary 'thr' if present; else fall back to the top-level 'threshold'
    thr = s.get("thr", rec.get("threshold", float("nan")))
    row = {
        "model": model_name,
        "threshold": float(thr) if thr is not None and not isinstance(thr, str) else float("nan"),
        "acc": float(s.get("acc", float("nan"))),
        "precision": float(s.get("precision", float("nan"))),
        "recall": float(s.get("recall", float("nan"))),
        "f1": float(s.get("f1", float("nan"))),
        "auroc": float(s.get("auroc", float("nan"))),
        "params": rec.get("params", None),
        "time_sec": rec.get("time_sec", None),
    }
    return row

# Build both tables from the registry
rows_recall = []
rows_thr05 = []
for name, rec in result_registry.items():
    rows_recall.append(_extract_row(name, rec, "summary@recall"))
    rows_thr05.append(_extract_row(name, rec, "summary@0.5"))

df_recall = pd.DataFrame(rows_recall)
df_thr05  = pd.DataFrame(rows_thr05)

# Add convenience columns and formatting
def _format(df: pd.DataFrame, check_target=False) -> pd.DataFrame:
    df = df.copy()
    # Params in millions; training time in minutes
    if "params" in df:
        df["params (M)"] = df["params"].apply(lambda x: round(x/1e6, 2) if pd.notna(x) else math.nan)
    if "time_sec" in df:
        df["time (min)"] = df["time_sec"].apply(lambda x: round(x/60.0, 1) if pd.notna(x) else math.nan)

    # Human-friendly rounding
    if "threshold" in df: df["threshold"] = df["threshold"].round(3)
    for c in ["acc","precision","recall","f1","auroc"]:
        if c in df:
            df[c] = (df[c] * 100.0).round(2)  # show as %
    # Optional flag: did this row meet the target recall?
    if check_target and "recall" in df:
        df["meets_target(≥95%)"] = df["recall"].apply(lambda r: (pd.notna(r) and r >= TARGET_RECALL*100.0))
    # Reorder columns
    cols = ["model","threshold","acc","precision","recall","f1","auroc","params (M)","time (min)"]
    cols = [c for c in cols if c in df.columns]
    return df[cols]

# Sort by AUROC (desc) as a stable default; change to 'f1' if you prefer
df_recall = df_recall.sort_values(by="auroc", ascending=False).reset_index(drop=True)
df_thr05  = df_thr05.sort_values(by="auroc", ascending=False).reset_index(drop=True)

df_recall = _format(df_recall, check_target=True)
df_thr05  = _format(df_thr05,  check_target=False)

# Display
print("=== Table A — Metrics at threshold chosen to reach Recall ≥ 95% ===")
display(df_recall.style.format({
    "threshold": "{:.3f}",
    "acc": "{:.2f}%", "precision": "{:.2f}%", "recall": "{:.2f}%", "f1": "{:.2f}%", "auroc": "{:.2f}%",
    "params (M)": "{:.2f}", "time (min)": "{:.1f}"
}).set_properties(**{"text-align": "center"}))

print("\n=== Table B — Metrics at fixed threshold = 0.50 ===")
display(df_thr05.style.format({
    "threshold": "{:.3f}",
    "acc": "{:.2f}%", "precision": "{:.2f}%", "recall": "{:.2f}%", "f1": "{:.2f}%", "auroc": "{:.2f}%",
    "params (M)": "{:.2f}", "time (min)": "{:.1f}"
}).set_properties(**{"text-align": "center"}))

# (Optional) Save to CSV alongside the notebook
# df_recall.to_csv("results_table_recall>=95.csv", index=False)
# df_thr05.to_csv("results_table_thr=0.5.csv", index=False)
# Out:
# === Table A — Metrics at threshold chosen to reach Recall ≥ 95% ===
# <style type="text/css">
# #T_621c3_row0_col0, #T_621c3_row0_col1, #T_621c3_row0_col2, #T_621c3_row0_col3, #T_621c3_row0_col4, #T_621c3_row0_col5, #T_621c3_row0_col6, #T_621c3_row0_col7, #T_621c3_row0_col8, #T_621c3_row1_col0, #T_621c3_row1_col1, #T_621c3_row1_col2, #T_621c3_row1_col3, #T_621c3_row1_col4, #T_621c3_row1_col5, #T_621c3_row1_col6, #T_621c3_row1_col7, #T_621c3_row1_col8, #T_621c3_row2_col0, #T_621c3_row2_col1, #T_621c3_row2_col2, #T_621c3_row2_col3, #T_621c3_row2_col4, #T_621c3_row2_col5, #T_621c3_row2_col6, #T_621c3_row2_col7, #T_621c3_row2_col8 {
#   text-align: center;
# }
# </style>
# <table id="T_621c3" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_621c3_level0_col0" class="col_heading level0 col0" >model</th>
#       <th id="T_621c3_level0_col1" class="col_heading level0 col1" >threshold</th>
#       <th id="T_621c3_level0_col2" class="col_heading level0 col2" >acc</th>
#       <th id="T_621c3_level0_col3" class="col_heading level0 col3" >precision</th>
#       <th id="T_621c3_level0_col4" class="col_heading level0 col4" >recall</th>
#       <th id="T_621c3_level0_col5" class="col_heading level0 col5" >f1</th>
#       <th id="T_621c3_level0_col6" class="col_heading level0 col6" >auroc</th>
#       <th id="T_621c3_level0_col7" class="col_heading level0 col7" >params (M)</th>
#       <th id="T_621c3_level0_col8" class="col_heading level0 col8" >time (min)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_621c3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_621c3_row0_col0" class="data row0 col0" >ViT (scratch+SAM, 3ch)</td>
#       <td id="T_621c3_row0_col1" class="data row0 col1" >0.135</td>
#       <td id="T_621c3_row0_col2" class="data row0 col2" >86.22%</td>
#       <td id="T_621c3_row0_col3" class="data row0 col3" >83.04%</td>
#       <td id="T_621c3_row0_col4" class="data row0 col4" >97.95%</td>
#       <td id="T_621c3_row0_col5" class="data row0 col5" >89.88%</td>
#       <td id="T_621c3_row0_col6" class="data row0 col6" >94.30%</td>
#       <td id="T_621c3_row0_col7" class="data row0 col7" >21.67</td>
#       <td id="T_621c3_row0_col8" class="data row0 col8" >72.8</td>
#     </tr>
#     <tr>
#       <th id="T_621c3_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_621c3_row1_col0" class="data row1 col0" >ResNet18 (scratch+SAM, 3ch)</td>
#       <td id="T_621c3_row1_col1" class="data row1 col1" >0.351</td>
#       <td id="T_621c3_row1_col2" class="data row1 col2" >84.29%</td>
#       <td id="T_621c3_row1_col3" class="data row1 col3" >80.67%</td>
#       <td id="T_621c3_row1_col4" class="data row1 col4" >98.46%</td>
#       <td id="T_621c3_row1_col5" class="data row1 col5" >88.68%</td>
#       <td id="T_621c3_row1_col6" class="data row1 col6" >93.12%</td>
#       <td id="T_621c3_row1_col7" class="data row1 col7" >11.18</td>
#       <td id="T_621c3_row1_col8" class="data row1 col8" >6.6</td>
#     </tr>
#     <tr>
#       <th id="T_621c3_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_621c3_row2_col0" class="data row2 col0" >CustomCNN (scratch+SAM, 3ch)</td>
#       <td id="T_621c3_row2_col1" class="data row2 col1" >0.342</td>
#       <td id="T_621c3_row2_col2" class="data row2 col2" >78.04%</td>
#       <td id="T_621c3_row2_col3" class="data row2 col3" >74.85%</td>
#       <td id="T_621c3_row2_col4" class="data row2 col4" >97.69%</td>
#       <td id="T_621c3_row2_col5" class="data row2 col5" >84.76%</td>
#       <td id="T_621c3_row2_col6" class="data row2 col6" >92.00%</td>
#       <td id="T_621c3_row2_col7" class="data row2 col7" >0.48</td>
#       <td id="T_621c3_row2_col8" class="data row2 col8" >31.1</td>
#     </tr>
#   </tbody>
# </table>
# === Table B — Metrics at fixed threshold = 0.50 ===
# <style type="text/css">
# #T_857b9_row0_col0, #T_857b9_row0_col1, #T_857b9_row0_col2, #T_857b9_row0_col3, #T_857b9_row0_col4, #T_857b9_row0_col5, #T_857b9_row0_col6, #T_857b9_row0_col7, #T_857b9_row0_col8, #T_857b9_row1_col0, #T_857b9_row1_col1, #T_857b9_row1_col2, #T_857b9_row1_col3, #T_857b9_row1_col4, #T_857b9_row1_col5, #T_857b9_row1_col6, #T_857b9_row1_col7, #T_857b9_row1_col8, #T_857b9_row2_col0, #T_857b9_row2_col1, #T_857b9_row2_col2, #T_857b9_row2_col3, #T_857b9_row2_col4, #T_857b9_row2_col5, #T_857b9_row2_col6, #T_857b9_row2_col7, #T_857b9_row2_col8 {
#   text-align: center;
# }
# </style>
# <table id="T_857b9" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_857b9_level0_col0" class="col_heading level0 col0" >model</th>
#       <th id="T_857b9_level0_col1" class="col_heading level0 col1" >threshold</th>
#       <th id="T_857b9_level0_col2" class="col_heading level0 col2" >acc</th>
#       <th id="T_857b9_level0_col3" class="col_heading level0 col3" >precision</th>
#       <th id="T_857b9_level0_col4" class="col_heading level0 col4" >recall</th>
#       <th id="T_857b9_level0_col5" class="col_heading level0 col5" >f1</th>
#       <th id="T_857b9_level0_col6" class="col_heading level0 col6" >auroc</th>
#       <th id="T_857b9_level0_col7" class="col_heading level0 col7" >params (M)</th>
#       <th id="T_857b9_level0_col8" class="col_heading level0 col8" >time (min)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_857b9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_857b9_row0_col0" class="data row0 col0" >ViT (scratch+SAM, 3ch)</td>
#       <td id="T_857b9_row0_col1" class="data row0 col1" >0.500</td>
#       <td id="T_857b9_row0_col2" class="data row0 col2" >88.46%</td>
#       <td id="T_857b9_row0_col3" class="data row0 col3" >90.36%</td>
#       <td id="T_857b9_row0_col4" class="data row0 col4" >91.28%</td>
#       <td id="T_857b9_row0_col5" class="data row0 col5" >90.82%</td>
#       <td id="T_857b9_row0_col6" class="data row0 col6" >94.30%</td>
#       <td id="T_857b9_row0_col7" class="data row0 col7" >21.67</td>
#       <td id="T_857b9_row0_col8" class="data row0 col8" >72.8</td>
#     </tr>
#     <tr>
#       <th id="T_857b9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_857b9_row1_col0" class="data row1 col0" >ResNet18 (scratch+SAM, 3ch)</td>
#       <td id="T_857b9_row1_col1" class="data row1 col1" >0.500</td>
#       <td id="T_857b9_row1_col2" class="data row1 col2" >87.98%</td>
#       <td id="T_857b9_row1_col3" class="data row1 col3" >86.37%</td>
#       <td id="T_857b9_row1_col4" class="data row1 col4" >95.90%</td>
#       <td id="T_857b9_row1_col5" class="data row1 col5" >90.89%</td>
#       <td id="T_857b9_row1_col6" class="data row1 col6" >93.12%</td>
#       <td id="T_857b9_row1_col7" class="data row1 col7" >11.18</td>
#       <td id="T_857b9_row1_col8" class="data row1 col8" >6.6</td>
#     </tr>
#     <tr>
#       <th id="T_857b9_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_857b9_row2_col0" class="data row2 col0" >CustomCNN (scratch+SAM, 3ch)</td>
#       <td id="T_857b9_row2_col1" class="data row2 col1" >0.500</td>
#       <td id="T_857b9_row2_col2" class="data row2 col2" >83.01%</td>
#       <td id="T_857b9_row2_col3" class="data row2 col3" >81.56%</td>
#       <td id="T_857b9_row2_col4" class="data row2 col4" >94.10%</td>
#       <td id="T_857b9_row2_col5" class="data row2 col5" >87.38%</td>
#       <td id="T_857b9_row2_col6" class="data row2 col6" >92.00%</td>
#       <td id="T_857b9_row2_col7" class="data row2 col7" >0.48</td>
#       <td id="T_857b9_row2_col8" class="data row2 col8" >31.1</td>
#     </tr>
#   </tbody>
# </table>
