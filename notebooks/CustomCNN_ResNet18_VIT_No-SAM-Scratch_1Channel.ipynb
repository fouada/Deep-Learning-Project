# %% [markdown]
# # Scratch baselines without SAM — CustomCNN, ResNet18, ViT
# - Same preprocessing, cosine+warmup schedule, early stopping on AUROC.
# - Final metrics shown at 0.5 and at a *recall‑first* operating point (screening).

# %%
# Clean imports + path setup
import sys, time, warnings
from pathlib import Path
try:
    from tqdm.auto import tqdm
except Exception:
    from tqdm import tqdm
from tqdm import TqdmWarning
warnings.filterwarnings("ignore", category=TqdmWarning)

# Resolve project root (directory containing `src/`)
proj_root = Path.cwd()
for _ in range(5):
    if (proj_root / "src").exists(): break
    proj_root = proj_root.parent
if str(proj_root) not in sys.path:
    sys.path.insert(0, str(proj_root))
print("proj_root:", proj_root)

# Project imports
from src import (
    DataCfg, TrainCfg, build_dataloaders, get_device, set_seed,
    build_custom_cnn, build_resnet18, build_vit_scratch,
    train_model, evaluate, choose_threshold_by_min_recall,
    summarize_at_threshold, plot_curve, plot_two_series, diag_plots,
    add_result, result_registry
)

import numpy as np, torch
set_seed(42)
DEVICE = get_device()
DEVICE
# Out:
# proj_root: /Users/fouadaz/LearningFromUniversity/Learning/DeepLearning_2025/Deep-Learning-Project
# device(type='mps')

# %%
# === Paths/config ===
DATASET_DIR = Path("../Data/chest_xray")  # <--- EDIT THIS IF NEEDED

# Keep split identical across notebooks for fair comparison
data_cfg = DataCfg(
    dataset_dir=DATASET_DIR,
    image_size=224,
    batch_size=32,
    num_workers=0,          # 0 on macOS avoids "MallocStackLogging" noise
    pin_memory=True,
    use_stratified_val=True,
    val_ratio=0.20,         # use the same val split you used elsewhere
    gray_to_rgb=False,      # <<< 1-CHANNEL grayscale
    compute_norm_stats=True,# <<< compute mean/std for 1 channel from train set
    balance_sampler=True
)

train_loader, val_loader, test_loader, info = build_dataloaders(data_cfg, device=DEVICE)
print("Classes:", info["classes"])
print("Lens:", info["n_train"], info["n_val"], info["n_test"])
print("Train counts:", info["train_counts"])

# Class weights: when balance_sampler=True, set None to avoid double-correction
class_weights = None

# Sanity check: confirm 1-channel
xb, yb = next(iter(train_loader))
print("Batch shape:", tuple(xb.shape))  # expect (B, 1, 224, 224)
del xb, yb
# Out:
# Classes: ['NORMAL', 'PNEUMONIA']
# Lens: 4185 1047 624
# Train counts: [1079, 3106]
# Batch shape: (32, 1, 224, 224)

# %%
# Shared training cfg "envelope" for scratch runs with SAM OFF
scratch_no_sam = TrainCfg(
    epochs=100, patience=15, monitor="va_auroc",
    base_lr=3e-4, weight_decay=0.3,   # <- ViT defaults; CNN/ResNet override below
    clip_grad_norm=1.0, use_amp=False,
    use_sam=False, sam_rho=0.0,       # SAM OFF
    use_cosine=True, warmup_epochs=3, min_lr_mult=0.01,
    target_recall=0.95,
    llrd=False, head_lr_mult=1.0
)

# %%
cfg = scratch_no_sam

cnn = build_custom_cnn(in_chans=1, num_classes=2, width=32, dropout=0.0)  # <<< in_chans=1
t0 = time.time()
cnn_tr, cnn_hist, cnn_time = train_model(
    cnn, train_loader, val_loader, DEVICE, arch="custom_cnn",
    epochs=cfg.epochs, base_lr=0.1, weight_decay=1e-3, label_smoothing=0.0,
    use_sam=False, sam_rho=0.0,
    use_cosine=cfg.use_cosine, warmup_epochs=cfg.warmup_epochs, min_lr_mult=cfg.min_lr_mult,
    monitor=cfg.monitor, patience=cfg.patience, clip_grad_norm=cfg.clip_grad_norm,
    class_weights=class_weights, llrd=False, head_lr_mult=cfg.head_lr_mult, use_amp=cfg.use_amp,
    tag="CustomCNN-scratch-1ch"
)
cnn_time = time.time() - t0

plot_curve(cnn_hist['tr_loss'], cnn_hist['va_loss'], "CustomCNN (1ch, no SAM) — Loss")
plot_two_series(cnn_hist['va_acc'], "Val Acc", cnn_hist['va_f1'], "Val F1", "CustomCNN (1ch, no SAM) — Val")

va = evaluate(cnn_tr, val_loader, DEVICE)
thr, *_ = choose_threshold_by_min_recall(va["targets"], va["probs"][:,1], cfg.target_recall)
te = evaluate(cnn_tr, test_loader, DEVICE)
sum_05   = summarize_at_threshold(te["targets"], te["probs"][:,1], 0.5)
sum_reca = summarize_at_threshold(te["targets"], te["probs"][:,1], thr)
print("[CustomCNN-1ch @0.5]", {k: round(v,4) for k,v in sum_05.items()})
print("[CustomCNN-1ch @Rec]", {k: round(v,4) for k,v in sum_reca.items()})
diag_plots("CustomCNN (scratch, 1ch)", te["probs"], te["targets"], thr, auroc=te.get("auroc"))
add_result("CustomCNN (scratch, 1ch)", cnn_tr, sum_05, sum_reca, threshold=thr, time_sec=cnn_time)
# Out:
# [CustomCNN-scratch-1ch] epoch 01/100  tr_loss=0.4778  val_loss=0.5483  val_acc=0.7841  val_f1=0.8311  val_auroc=0.9402  (no_improve=0)
# [CustomCNN-scratch-1ch] epoch 02/100  tr_loss=0.4655  val_loss=0.3706  val_acc=0.7937  val_f1=0.8770  val_auroc=0.9278  (no_improve=1)
# [CustomCNN-scratch-1ch] epoch 03/100  tr_loss=0.4505  val_loss=0.4457  val_acc=0.8204  val_f1=0.8665  val_auroc=0.9178  (no_improve=2)
# [CustomCNN-scratch-1ch] epoch 04/100  tr_loss=0.4022  val_loss=0.3352  val_acc=0.8109  val_f1=0.8841  val_auroc=0.9327  (no_improve=3)
# [CustomCNN-scratch-1ch] epoch 05/100  tr_loss=0.4132  val_loss=0.2925  val_acc=0.8825  val_f1=0.9163  val_auroc=0.9475  (no_improve=0)
# [CustomCNN-scratch-1ch] epoch 06/100  tr_loss=0.3859  val_loss=0.2861  val_acc=0.8863  val_f1=0.9194  val_auroc=0.9401  (no_improve=1)
# [CustomCNN-scratch-1ch] epoch 07/100  tr_loss=0.3749  val_loss=0.2660  val_acc=0.8835  val_f1=0.9219  val_auroc=0.9441  (no_improve=2)
# [CustomCNN-scratch-1ch] epoch 08/100  tr_loss=0.3721  val_loss=0.6265  val_acc=0.7765  val_f1=0.8243  val_auroc=0.9391  (no_improve=3)
# [CustomCNN-scratch-1ch] epoch 09/100  tr_loss=0.3885  val_loss=0.3131  val_acc=0.8682  val_f1=0.9051  val_auroc=0.9514  (no_improve=0)
# [CustomCNN-scratch-1ch] epoch 10/100  tr_loss=0.3779  val_loss=0.9422  val_acc=0.7192  val_f1=0.7670  val_auroc=0.9334  (no_improve=1)
# [CustomCNN-scratch-1ch] epoch 11/100  tr_loss=0.3857  val_loss=0.6217  val_acc=0.7670  val_f1=0.8157  val_auroc=0.9422  (no_improve=2)
# [CustomCNN-scratch-1ch] epoch 12/100  tr_loss=0.3895  val_loss=0.3736  val_acc=0.8462  val_f1=0.8900  val_auroc=0.9171  (no_improve=3)
# [CustomCNN-scratch-1ch] epoch 13/100  tr_loss=0.3815  val_loss=0.5517  val_acc=0.7459  val_f1=0.8532  val_auroc=0.9332  (no_improve=4)
# [CustomCNN-scratch-1ch] epoch 14/100  tr_loss=0.3685  val_loss=0.4429  val_acc=0.8223  val_f1=0.8668  val_auroc=0.9479  (no_improve=5)
# [CustomCNN-scratch-1ch] epoch 15/100  tr_loss=0.3930  val_loss=0.2647  val_acc=0.8921  val_f1=0.9253  val_auroc=0.9547  (no_improve=0)
# [CustomCNN-scratch-1ch] epoch 16/100  tr_loss=0.3888  val_loss=0.2375  val_acc=0.8978  val_f1=0.9321  val_auroc=0.9550  (no_improve=0)
# [CustomCNN-scratch-1ch] epoch 17/100  tr_loss=0.3854  val_loss=0.2755  val_acc=0.8768  val_f1=0.9136  val_auroc=0.9387  (no_improve=1)
# [CustomCNN-scratch-1ch] epoch 18/100  tr_loss=0.3774  val_loss=0.2966  val_acc=0.8682  val_f1=0.9051  val_auroc=0.9551  (no_improve=0)
# [CustomCNN-scratch-1ch] epoch 19/100  tr_loss=0.3771  val_loss=0.4331  val_acc=0.8491  val_f1=0.8887  val_auroc=0.9362  (no_improve=1)
# [CustomCNN-scratch-1ch] epoch 20/100  tr_loss=0.3613  val_loss=0.3373  val_acc=0.8787  val_f1=0.9128  val_auroc=0.9424  (no_improve=2)
# [CustomCNN-scratch-1ch] epoch 21/100  tr_loss=0.3598  val_loss=0.8070  val_acc=0.6628  val_f1=0.7080  val_auroc=0.9249  (no_improve=3)
# [CustomCNN-scratch-1ch] epoch 22/100  tr_loss=0.3537  val_loss=0.5859  val_acc=0.7536  val_f1=0.8563  val_auroc=0.9096  (no_improve=4)
# [CustomCNN-scratch-1ch] epoch 23/100  tr_loss=0.3925  val_loss=0.7677  val_acc=0.6743  val_f1=0.7198  val_auroc=0.9548  (no_improve=5)
# [CustomCNN-scratch-1ch] epoch 24/100  tr_loss=0.3587  val_loss=0.4129  val_acc=0.8462  val_f1=0.8864  val_auroc=0.9482  (no_improve=6)
# [CustomCNN-scratch-1ch] epoch 25/100  tr_loss=0.3594  val_loss=0.3776  val_acc=0.8453  val_f1=0.8846  val_auroc=0.9635  (no_improve=0)
# [CustomCNN-scratch-1ch] epoch 26/100  tr_loss=0.3644  val_loss=0.3664  val_acc=0.8596  val_f1=0.8974  val_auroc=0.9731  (no_improve=0)
# [CustomCNN-scratch-1ch] epoch 27/100  tr_loss=0.3700  val_loss=1.0480  val_acc=0.5043  val_f1=0.4986  val_auroc=0.9686  (no_improve=1)
# [CustomCNN-scratch-1ch] epoch 28/100  tr_loss=0.3688  val_loss=0.4731  val_acc=0.8233  val_f1=0.8687  val_auroc=0.9320  (no_improve=2)
# [CustomCNN-scratch-1ch] epoch 29/100  tr_loss=0.3620  val_loss=0.6631  val_acc=0.7431  val_f1=0.7923  val_auroc=0.9402  (no_improve=3)
# [CustomCNN-scratch-1ch] epoch 30/100  tr_loss=0.3612  val_loss=0.3114  val_acc=0.8873  val_f1=0.9204  val_auroc=0.9502  (no_improve=4)
# [CustomCNN-scratch-1ch] epoch 31/100  tr_loss=0.3513  val_loss=0.2899  val_acc=0.8701  val_f1=0.9062  val_auroc=0.9627  (no_improve=5)
# [CustomCNN-scratch-1ch] epoch 32/100  tr_loss=0.3388  val_loss=0.5016  val_acc=0.8252  val_f1=0.8675  val_auroc=0.9482  (no_improve=6)
# [CustomCNN-scratch-1ch] epoch 33/100  tr_loss=0.3452  val_loss=0.3495  val_acc=0.8567  val_f1=0.8951  val_auroc=0.9614  (no_improve=7)
# [CustomCNN-scratch-1ch] epoch 34/100  tr_loss=0.3512  val_loss=0.3422  val_acc=0.8558  val_f1=0.8958  val_auroc=0.9465  (no_improve=8)
# [CustomCNN-scratch-1ch] epoch 35/100  tr_loss=0.3657  val_loss=1.2176  val_acc=0.4833  val_f1=0.4659  val_auroc=0.9542  (no_improve=9)
# [CustomCNN-scratch-1ch] epoch 36/100  tr_loss=0.3525  val_loss=0.3000  val_acc=0.8968  val_f1=0.9281  val_auroc=0.9660  (no_improve=10)
# [CustomCNN-scratch-1ch] epoch 37/100  tr_loss=0.3482  val_loss=0.4730  val_acc=0.8252  val_f1=0.8681  val_auroc=0.9692  (no_improve=11)
# [CustomCNN-scratch-1ch] epoch 38/100  tr_loss=0.3330  val_loss=0.2750  val_acc=0.8921  val_f1=0.9244  val_auroc=0.9582  (no_improve=12)
# [CustomCNN-scratch-1ch] epoch 39/100  tr_loss=0.3278  val_loss=0.2749  val_acc=0.8644  val_f1=0.9143  val_auroc=0.9584  (no_improve=13)
# [CustomCNN-scratch-1ch] epoch 40/100  tr_loss=0.3612  val_loss=0.2563  val_acc=0.8892  val_f1=0.9277  val_auroc=0.9533  (no_improve=14)
# [CustomCNN-scratch-1ch] epoch 41/100  tr_loss=0.3278  val_loss=0.3983  val_acc=0.8491  val_f1=0.8884  val_auroc=0.9678  (no_improve=15)
# [CustomCNN-scratch-1ch] early stopping at epoch 41.
# [CustomCNN-1ch @0.5] {'acc': 0.8526, 'precision': 0.888, 'recall': 0.8744, 'f1': 0.8811, 'auroc': 0.9198, 'thr': 0.5}
# [CustomCNN-1ch @Rec] {'acc': 0.8413, 'precision': 0.8129, 'recall': 0.9692, 'f1': 0.8842, 'auroc': 0.9198, 'thr': 0.3135}
# {'summary@0.5': {'acc': 0.8525641025641025,
#   'precision': 0.8880208333333334,
#   'recall': 0.8743589743589744,
#   'f1': 0.8811369509043928,
#   'auroc': 0.9198444006136313,
#   'thr': 0.5},
#  'summary@recall': {'acc': 0.8413461538461539,
#   'precision': 0.8129032258064516,
#   'recall': 0.9692307692307692,
#   'f1': 0.8842105263157894,
#   'auroc': 0.9198444006136313,
#   'thr': 0.3135},
#  'threshold': 0.3135,
#  'time_sec': 3448.64901304245,
#  'params': 481122}

# %%
rn = build_resnet18(in_chans=1, num_classes=2, pretrained=False, conv_stem=False)  # <<< in_chans=1
t0 = time.time()
rn_tr, rn_hist, rn_time = train_model(
    rn, train_loader, val_loader, DEVICE, arch="resnet18",
    epochs=90, base_lr=0.1, weight_decay=1e-3, label_smoothing=0.0,
    use_sam=False, sam_rho=0.0,
    use_cosine=cfg.use_cosine, warmup_epochs=cfg.warmup_epochs, min_lr_mult=cfg.min_lr_mult,
    monitor=cfg.monitor, patience=10, clip_grad_norm=cfg.clip_grad_norm,
    class_weights=class_weights, llrd=False, head_lr_mult=cfg.head_lr_mult, use_amp=cfg.use_amp,
    tag="ResNet18-scratch-1ch"
)
rn_time = time.time() - t0

plot_curve(rn_hist['tr_loss'], rn_hist['va_loss'], "ResNet18 (1ch, no SAM) — Loss")
plot_two_series(rn_hist['va_acc'], "Val Acc", rn_hist['va_f1'], "Val F1", "ResNet18 (1ch, no SAM) — Val")

va = evaluate(rn_tr, val_loader, DEVICE)
thr, *_ = choose_threshold_by_min_recall(va["targets"], va["probs"][:,1], cfg.target_recall)
te = evaluate(rn_tr, test_loader, DEVICE)
sum_05   = summarize_at_threshold(te["targets"], te["probs"][:,1], 0.5)
sum_reca = summarize_at_threshold(te["targets"], te["probs"][:,1], thr)
print("[ResNet18-1ch @0.5]", {k: round(v,4) for k,v in sum_05.items()})
print("[ResNet18-1ch @Rec]", {k: round(v,4) for k,v in sum_reca.items()})
diag_plots("ResNet18 (scratch, 1ch)", te["probs"], te["targets"], thr, auroc=te.get("auroc"))
add_result("ResNet18 (scratch, 1ch)", rn_tr, sum_05, sum_reca, threshold=thr, time_sec=rn_time)
# Out:
# [ResNet18-scratch-1ch] epoch 01/90  tr_loss=0.4808  val_loss=0.2812  val_acc=0.8787  val_f1=0.9127  val_auroc=0.9686  (no_improve=0)
# [ResNet18-scratch-1ch] epoch 02/90  tr_loss=0.5744  val_loss=0.9565  val_acc=0.7689  val_f1=0.8167  val_auroc=0.9644  (no_improve=1)
# [ResNet18-scratch-1ch] epoch 03/90  tr_loss=0.5956  val_loss=0.3739  val_acc=0.8711  val_f1=0.9086  val_auroc=0.9423  (no_improve=2)
# [ResNet18-scratch-1ch] epoch 04/90  tr_loss=0.4599  val_loss=0.2608  val_acc=0.8816  val_f1=0.9193  val_auroc=0.9456  (no_improve=3)
# [ResNet18-scratch-1ch] epoch 05/90  tr_loss=0.4066  val_loss=0.2201  val_acc=0.8940  val_f1=0.9244  val_auroc=0.9743  (no_improve=0)
# [ResNet18-scratch-1ch] epoch 06/90  tr_loss=0.3578  val_loss=0.2000  val_acc=0.9083  val_f1=0.9385  val_auroc=0.9672  (no_improve=1)
# [ResNet18-scratch-1ch] epoch 07/90  tr_loss=0.3427  val_loss=0.2695  val_acc=0.8653  val_f1=0.9022  val_auroc=0.9704  (no_improve=2)
# [ResNet18-scratch-1ch] epoch 08/90  tr_loss=0.3502  val_loss=0.2124  val_acc=0.9121  val_f1=0.9390  val_auroc=0.9730  (no_improve=3)
# [ResNet18-scratch-1ch] epoch 09/90  tr_loss=0.3415  val_loss=0.2969  val_acc=0.8701  val_f1=0.9053  val_auroc=0.9777  (no_improve=0)
# [ResNet18-scratch-1ch] epoch 10/90  tr_loss=0.3202  val_loss=0.3103  val_acc=0.8691  val_f1=0.9048  val_auroc=0.9755  (no_improve=1)
# [ResNet18-scratch-1ch] epoch 11/90  tr_loss=0.3335  val_loss=0.2330  val_acc=0.8988  val_f1=0.9290  val_auroc=0.9669  (no_improve=2)
# [ResNet18-scratch-1ch] epoch 12/90  tr_loss=0.3396  val_loss=0.2208  val_acc=0.9083  val_f1=0.9359  val_auroc=0.9785  (no_improve=0)
# [ResNet18-scratch-1ch] epoch 13/90  tr_loss=0.3094  val_loss=0.3446  val_acc=0.8711  val_f1=0.9054  val_auroc=0.9797  (no_improve=0)
# [ResNet18-scratch-1ch] epoch 14/90  tr_loss=0.3337  val_loss=0.2337  val_acc=0.9102  val_f1=0.9363  val_auroc=0.9765  (no_improve=1)
# [ResNet18-scratch-1ch] epoch 15/90  tr_loss=0.3239  val_loss=0.3594  val_acc=0.8271  val_f1=0.8686  val_auroc=0.9857  (no_improve=0)
# [ResNet18-scratch-1ch] epoch 16/90  tr_loss=0.3141  val_loss=0.1663  val_acc=0.9522  val_f1=0.9679  val_auroc=0.9829  (no_improve=1)
# [ResNet18-scratch-1ch] epoch 17/90  tr_loss=0.3152  val_loss=0.1660  val_acc=0.9274  val_f1=0.9495  val_auroc=0.9846  (no_improve=2)
# [ResNet18-scratch-1ch] epoch 18/90  tr_loss=0.3172  val_loss=0.1745  val_acc=0.9293  val_f1=0.9513  val_auroc=0.9810  (no_improve=3)
# [ResNet18-scratch-1ch] epoch 19/90  tr_loss=0.3112  val_loss=0.3471  val_acc=0.8567  val_f1=0.8942  val_auroc=0.9731  (no_improve=4)
# [ResNet18-scratch-1ch] epoch 20/90  tr_loss=0.3292  val_loss=0.1749  val_acc=0.9456  val_f1=0.9631  val_auroc=0.9818  (no_improve=5)
# [ResNet18-scratch-1ch] epoch 21/90  tr_loss=0.3138  val_loss=0.2108  val_acc=0.9245  val_f1=0.9476  val_auroc=0.9812  (no_improve=6)
# [ResNet18-scratch-1ch] epoch 22/90  tr_loss=0.3068  val_loss=0.3211  val_acc=0.8644  val_f1=0.9000  val_auroc=0.9842  (no_improve=7)
# [ResNet18-scratch-1ch] epoch 23/90  tr_loss=0.3065  val_loss=0.2288  val_acc=0.8988  val_f1=0.9349  val_auroc=0.9723  (no_improve=8)
# [ResNet18-scratch-1ch] epoch 24/90  tr_loss=0.3007  val_loss=0.3497  val_acc=0.8472  val_f1=0.8856  val_auroc=0.9832  (no_improve=9)
# [ResNet18-scratch-1ch] epoch 25/90  tr_loss=0.3029  val_loss=0.3421  val_acc=0.8415  val_f1=0.8809  val_auroc=0.9839  (no_improve=10)
# [ResNet18-scratch-1ch] early stopping at epoch 25.
# [ResNet18-1ch @0.5] {'acc': 0.8494, 'precision': 0.8957, 'recall': 0.859, 'f1': 0.877, 'auroc': 0.9171, 'thr': 0.5}
# [ResNet18-1ch @Rec] {'acc': 0.7997, 'precision': 0.7645, 'recall': 0.9821, 'f1': 0.8597, 'auroc': 0.9171, 'thr': 0.111}
# {'summary@0.5': {'acc': 0.8493589743589743,
#   'precision': 0.8957219251336899,
#   'recall': 0.8589743589743589,
#   'f1': 0.8769633507853403,
#   'auroc': 0.9171159325005478,
#   'thr': 0.5},
#  'summary@recall': {'acc': 0.7996794871794872,
#   'precision': 0.7644710578842315,
#   'recall': 0.982051282051282,
#   'f1': 0.8597081930415263,
#   'auroc': 0.9171159325005478,
#   'thr': 0.111},
#  'threshold': 0.111,
#  'time_sec': 1464.1912660598755,
#  'params': 11171266}

# %%
vit = build_vit_scratch(
    img_size=224, in_chans=1, num_classes=2,   # <<< in_chans=1
    embed_dim=384, depth=12, heads=6, patch=16, mlp_ratio=4.0, drop=0.1
)
t0 = time.time()
vit_tr, vit_hist, vit_time = train_model(
    vit, train_loader, val_loader, DEVICE, arch="vit",
    epochs=120, base_lr=3e-4, weight_decay=0.3, label_smoothing=0.0,
    use_sam=False, sam_rho=0.0,
    use_cosine=True, warmup_epochs=5, min_lr_mult=0.01,
    monitor="va_auroc", patience=15, clip_grad_norm=1.0,
    class_weights=class_weights, llrd=False, head_lr_mult=1.0, use_amp=False,
    tag="ViT-scratch-1ch"
)
vit_time = time.time() - t0

plot_curve(vit_hist['tr_loss'], vit_hist['va_loss'], "ViT (1ch, no SAM) — Loss")
plot_two_series(vit_hist['va_acc'], "Val Acc", vit_hist['va_f1'], "Val F1", "ViT (1ch, no SAM) — Val")

va = evaluate(vit_tr, val_loader, DEVICE)
thr, *_ = choose_threshold_by_min_recall(va["targets"], va["probs"][:,1], scratch_no_sam.target_recall)
te = evaluate(vit_tr, test_loader, DEVICE)
sum_05   = summarize_at_threshold(te["targets"], te["probs"][:,1], 0.5)
sum_reca = summarize_at_threshold(te["targets"], te["probs"][:,1], thr)
print("[ViT-1ch @0.5]", {k: round(v,4) for k,v in sum_05.items()})
print("[ViT-1ch @Rec]", {k: round(v,4) for k,v in sum_reca.items()})
diag_plots("ViT (scratch, 1ch)", te["probs"], te["targets"], thr, auroc=te.get("auroc"))
add_result("ViT (scratch, 1ch)", vit_tr, sum_05, sum_reca, threshold=thr, time_sec=vit_time)
# Out:
# [ViT-scratch-1ch] epoch 01/120  tr_loss=0.5906  val_loss=0.3279  val_acc=0.8672  val_f1=0.9049  val_auroc=0.9524  (no_improve=0)
# [ViT-scratch-1ch] epoch 02/120  tr_loss=0.5201  val_loss=0.7180  val_acc=0.7125  val_f1=0.7647  val_auroc=0.8856  (no_improve=1)
# [ViT-scratch-1ch] epoch 03/120  tr_loss=0.4857  val_loss=0.4475  val_acc=0.8090  val_f1=0.8534  val_auroc=0.9719  (no_improve=0)
# [ViT-scratch-1ch] epoch 04/120  tr_loss=0.5043  val_loss=0.3097  val_acc=0.8797  val_f1=0.9139  val_auroc=0.9550  (no_improve=1)
# [ViT-scratch-1ch] epoch 05/120  tr_loss=0.4648  val_loss=0.3552  val_acc=0.8443  val_f1=0.8846  val_auroc=0.9469  (no_improve=2)
# [ViT-scratch-1ch] epoch 06/120  tr_loss=0.4495  val_loss=0.2285  val_acc=0.9102  val_f1=0.9390  val_auroc=0.9627  (no_improve=3)
# [ViT-scratch-1ch] epoch 07/120  tr_loss=0.4123  val_loss=0.3103  val_acc=0.8863  val_f1=0.9192  val_auroc=0.9555  (no_improve=4)
# [ViT-scratch-1ch] epoch 08/120  tr_loss=0.4342  val_loss=0.4607  val_acc=0.7679  val_f1=0.8152  val_auroc=0.9665  (no_improve=5)
# [ViT-scratch-1ch] epoch 09/120  tr_loss=0.4182  val_loss=0.2910  val_acc=0.9045  val_f1=0.9331  val_auroc=0.9668  (no_improve=6)
# [ViT-scratch-1ch] epoch 10/120  tr_loss=0.4216  val_loss=0.3721  val_acc=0.8386  val_f1=0.8787  val_auroc=0.9740  (no_improve=0)
# [ViT-scratch-1ch] epoch 11/120  tr_loss=0.4125  val_loss=0.4331  val_acc=0.7985  val_f1=0.8441  val_auroc=0.9741  (no_improve=0)
# [ViT-scratch-1ch] epoch 12/120  tr_loss=0.3941  val_loss=0.3339  val_acc=0.8644  val_f1=0.9001  val_auroc=0.9752  (no_improve=0)
# [ViT-scratch-1ch] epoch 13/120  tr_loss=0.3912  val_loss=0.2917  val_acc=0.8863  val_f1=0.9187  val_auroc=0.9686  (no_improve=1)
# [ViT-scratch-1ch] epoch 14/120  tr_loss=0.3846  val_loss=0.2699  val_acc=0.8930  val_f1=0.9239  val_auroc=0.9709  (no_improve=2)
# [ViT-scratch-1ch] epoch 15/120  tr_loss=0.3838  val_loss=0.2490  val_acc=0.8911  val_f1=0.9223  val_auroc=0.9706  (no_improve=3)
# [ViT-scratch-1ch] epoch 16/120  tr_loss=0.3783  val_loss=0.2665  val_acc=0.8835  val_f1=0.9160  val_auroc=0.9721  (no_improve=4)
# [ViT-scratch-1ch] epoch 17/120  tr_loss=0.3795  val_loss=0.3639  val_acc=0.8481  val_f1=0.8872  val_auroc=0.9739  (no_improve=5)
# [ViT-scratch-1ch] epoch 18/120  tr_loss=0.3761  val_loss=0.4281  val_acc=0.8252  val_f1=0.8675  val_auroc=0.9689  (no_improve=6)
# [ViT-scratch-1ch] epoch 19/120  tr_loss=0.3747  val_loss=0.3639  val_acc=0.8625  val_f1=0.8983  val_auroc=0.9758  (no_improve=0)
# [ViT-scratch-1ch] epoch 20/120  tr_loss=0.3587  val_loss=0.2436  val_acc=0.9016  val_f1=0.9312  val_auroc=0.9693  (no_improve=1)
# [ViT-scratch-1ch] epoch 21/120  tr_loss=0.3632  val_loss=0.3641  val_acc=0.8500  val_f1=0.8884  val_auroc=0.9751  (no_improve=2)
# [ViT-scratch-1ch] epoch 22/120  tr_loss=0.3475  val_loss=0.3508  val_acc=0.8529  val_f1=0.8906  val_auroc=0.9790  (no_improve=0)
# [ViT-scratch-1ch] epoch 23/120  tr_loss=0.3569  val_loss=0.2918  val_acc=0.8730  val_f1=0.9082  val_auroc=0.9617  (no_improve=1)
# [ViT-scratch-1ch] epoch 24/120  tr_loss=0.3616  val_loss=0.2314  val_acc=0.8930  val_f1=0.9251  val_auroc=0.9630  (no_improve=2)
# [ViT-scratch-1ch] epoch 25/120  tr_loss=0.3880  val_loss=0.2489  val_acc=0.9083  val_f1=0.9345  val_auroc=0.9779  (no_improve=3)
# [ViT-scratch-1ch] epoch 26/120  tr_loss=0.3573  val_loss=0.2454  val_acc=0.8997  val_f1=0.9295  val_auroc=0.9651  (no_improve=4)
# [ViT-scratch-1ch] epoch 27/120  tr_loss=0.3457  val_loss=0.3784  val_acc=0.8472  val_f1=0.8856  val_auroc=0.9761  (no_improve=5)
# [ViT-scratch-1ch] epoch 28/120  tr_loss=0.3374  val_loss=0.3395  val_acc=0.8520  val_f1=0.8903  val_auroc=0.9661  (no_improve=6)
# [ViT-scratch-1ch] epoch 29/120  tr_loss=0.3728  val_loss=0.2758  val_acc=0.8730  val_f1=0.9074  val_auroc=0.9699  (no_improve=7)
# [ViT-scratch-1ch] epoch 30/120  tr_loss=0.3649  val_loss=0.2540  val_acc=0.8825  val_f1=0.9153  val_auroc=0.9717  (no_improve=8)
# [ViT-scratch-1ch] epoch 31/120  tr_loss=0.3589  val_loss=0.3013  val_acc=0.8625  val_f1=0.8996  val_auroc=0.9717  (no_improve=9)
# [ViT-scratch-1ch] epoch 32/120  tr_loss=0.3412  val_loss=0.3677  val_acc=0.8491  val_f1=0.8879  val_auroc=0.9762  (no_improve=10)
# [ViT-scratch-1ch] epoch 33/120  tr_loss=0.3626  val_loss=0.2895  val_acc=0.8873  val_f1=0.9196  val_auroc=0.9656  (no_improve=11)
# [ViT-scratch-1ch] epoch 34/120  tr_loss=0.3520  val_loss=0.2090  val_acc=0.9112  val_f1=0.9386  val_auroc=0.9698  (no_improve=12)
# [ViT-scratch-1ch] epoch 35/120  tr_loss=0.3349  val_loss=0.3766  val_acc=0.8462  val_f1=0.8856  val_auroc=0.9704  (no_improve=13)
# [ViT-scratch-1ch] epoch 36/120  tr_loss=0.3446  val_loss=0.2784  val_acc=0.8863  val_f1=0.9185  val_auroc=0.9658  (no_improve=14)
# [ViT-scratch-1ch] epoch 37/120  tr_loss=0.3490  val_loss=0.3231  val_acc=0.8730  val_f1=0.9071  val_auroc=0.9711  (no_improve=15)
# [ViT-scratch-1ch] early stopping at epoch 37.
# [ViT-1ch @0.5] {'acc': 0.8446, 'precision': 0.9036, 'recall': 0.841, 'f1': 0.8712, 'auroc': 0.9181, 'thr': 0.5}
# [ViT-1ch @Rec] {'acc': 0.8077, 'precision': 0.7801, 'recall': 0.9641, 'f1': 0.8624, 'auroc': 0.9181, 'thr': 0.1475}
# {'summary@0.5': {'acc': 0.844551282051282,
#   'precision': 0.9035812672176309,
#   'recall': 0.841025641025641,
#   'f1': 0.8711819389110226,
#   'auroc': 0.9180911680911681,
#   'thr': 0.5},
#  'summary@recall': {'acc': 0.8076923076923077,
#   'precision': 0.7800829875518672,
#   'recall': 0.9641025641025641,
#   'f1': 0.8623853211009175,
#   'auroc': 0.9180911680911681,
#   'thr': 0.1475},
#  'threshold': 0.1475,
#  'time_sec': 3795.443729877472,
#  'params': 21469826}

# %%
# === Final comparison tables across all models in this notebook ===
# Builds two tables:
#   (A) Metrics at the threshold that achieves Recall >= 0.95 (from summary@recall)
#   (B) Metrics at fixed threshold = 0.5 (from summary@0.5)
# Requires: from src import result_registry ; each model added via add_result(name, ...)

import math, pandas as pd
from src import result_registry

TARGET_RECALL = 0.95  # what "recall >= 95%" means

if not result_registry:
    raise RuntimeError("result_registry is empty. Make sure you called add_result(...) after each model.")

def _extract_row(model_name: str, rec: dict, which: str):
    """
    which: 'summary@recall' or 'summary@0.5'
    Returns a flat row with common columns.
    """
    s = rec.get(which, {}) or {}
    # Prefer the per-summary 'thr' if present; else fall back to the top-level 'threshold'
    thr = s.get("thr", rec.get("threshold", float("nan")))
    row = {
        "model": model_name,
        "threshold": float(thr) if thr is not None and not isinstance(thr, str) else float("nan"),
        "acc": float(s.get("acc", float("nan"))),
        "precision": float(s.get("precision", float("nan"))),
        "recall": float(s.get("recall", float("nan"))),
        "f1": float(s.get("f1", float("nan"))),
        "auroc": float(s.get("auroc", float("nan"))),
        "params": rec.get("params", None),
        "time_sec": rec.get("time_sec", None),
    }
    return row

# Build both tables from the registry
rows_recall = []
rows_thr05 = []
for name, rec in result_registry.items():
    rows_recall.append(_extract_row(name, rec, "summary@recall"))
    rows_thr05.append(_extract_row(name, rec, "summary@0.5"))

df_recall = pd.DataFrame(rows_recall)
df_thr05  = pd.DataFrame(rows_thr05)

# Add convenience columns and formatting
def _format(df: pd.DataFrame, check_target=False) -> pd.DataFrame:
    df = df.copy()
    # Params in millions; training time in minutes
    if "params" in df:
        df["params (M)"] = df["params"].apply(lambda x: round(x/1e6, 2) if pd.notna(x) else math.nan)
    if "time_sec" in df:
        df["time (min)"] = df["time_sec"].apply(lambda x: round(x/60.0, 1) if pd.notna(x) else math.nan)

    # Human-friendly rounding
    if "threshold" in df: df["threshold"] = df["threshold"].round(3)
    for c in ["acc","precision","recall","f1","auroc"]:
        if c in df:
            df[c] = (df[c] * 100.0).round(2)  # show as %
    # Optional flag: did this row meet the target recall?
    if check_target and "recall" in df:
        df["meets_target(≥95%)"] = df["recall"].apply(lambda r: (pd.notna(r) and r >= TARGET_RECALL*100.0))
    # Reorder columns
    cols = ["model","threshold","acc","precision","recall","f1","auroc","params (M)","time (min)"]
    cols = [c for c in cols if c in df.columns]
    return df[cols]

# Sort by AUROC (desc) as a stable default; change to 'f1' if you prefer
df_recall = df_recall.sort_values(by="auroc", ascending=False).reset_index(drop=True)
df_thr05  = df_thr05.sort_values(by="auroc", ascending=False).reset_index(drop=True)

df_recall = _format(df_recall, check_target=True)
df_thr05  = _format(df_thr05,  check_target=False)

# Display
print("=== Table A — Metrics at threshold chosen to reach Recall ≥ 95% ===")
display(df_recall.style.format({
    "threshold": "{:.3f}",
    "acc": "{:.2f}%", "precision": "{:.2f}%", "recall": "{:.2f}%", "f1": "{:.2f}%", "auroc": "{:.2f}%",
    "params (M)": "{:.2f}", "time (min)": "{:.1f}"
}).set_properties(**{"text-align": "center"}))

print("\n=== Table B — Metrics at fixed threshold = 0.50 ===")
display(df_thr05.style.format({
    "threshold": "{:.3f}",
    "acc": "{:.2f}%", "precision": "{:.2f}%", "recall": "{:.2f}%", "f1": "{:.2f}%", "auroc": "{:.2f}%",
    "params (M)": "{:.2f}", "time (min)": "{:.1f}"
}).set_properties(**{"text-align": "center"}))

# (Optional) Save to CSV alongside the notebook
# df_recall.to_csv("results_table_recall>=95.csv", index=False)
# df_thr05.to_csv("results_table_thr=0.5.csv", index=False)
# Out:
# === Table A — Metrics at threshold chosen to reach Recall ≥ 95% ===
# <style type="text/css">
# #T_30db1_row0_col0, #T_30db1_row0_col1, #T_30db1_row0_col2, #T_30db1_row0_col3, #T_30db1_row0_col4, #T_30db1_row0_col5, #T_30db1_row0_col6, #T_30db1_row0_col7, #T_30db1_row0_col8, #T_30db1_row1_col0, #T_30db1_row1_col1, #T_30db1_row1_col2, #T_30db1_row1_col3, #T_30db1_row1_col4, #T_30db1_row1_col5, #T_30db1_row1_col6, #T_30db1_row1_col7, #T_30db1_row1_col8, #T_30db1_row2_col0, #T_30db1_row2_col1, #T_30db1_row2_col2, #T_30db1_row2_col3, #T_30db1_row2_col4, #T_30db1_row2_col5, #T_30db1_row2_col6, #T_30db1_row2_col7, #T_30db1_row2_col8 {
#   text-align: center;
# }
# </style>
# <table id="T_30db1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_30db1_level0_col0" class="col_heading level0 col0" >model</th>
#       <th id="T_30db1_level0_col1" class="col_heading level0 col1" >threshold</th>
#       <th id="T_30db1_level0_col2" class="col_heading level0 col2" >acc</th>
#       <th id="T_30db1_level0_col3" class="col_heading level0 col3" >precision</th>
#       <th id="T_30db1_level0_col4" class="col_heading level0 col4" >recall</th>
#       <th id="T_30db1_level0_col5" class="col_heading level0 col5" >f1</th>
#       <th id="T_30db1_level0_col6" class="col_heading level0 col6" >auroc</th>
#       <th id="T_30db1_level0_col7" class="col_heading level0 col7" >params (M)</th>
#       <th id="T_30db1_level0_col8" class="col_heading level0 col8" >time (min)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_30db1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_30db1_row0_col0" class="data row0 col0" >CustomCNN (scratch, 1ch)</td>
#       <td id="T_30db1_row0_col1" class="data row0 col1" >0.314</td>
#       <td id="T_30db1_row0_col2" class="data row0 col2" >84.13%</td>
#       <td id="T_30db1_row0_col3" class="data row0 col3" >81.29%</td>
#       <td id="T_30db1_row0_col4" class="data row0 col4" >96.92%</td>
#       <td id="T_30db1_row0_col5" class="data row0 col5" >88.42%</td>
#       <td id="T_30db1_row0_col6" class="data row0 col6" >91.98%</td>
#       <td id="T_30db1_row0_col7" class="data row0 col7" >0.48</td>
#       <td id="T_30db1_row0_col8" class="data row0 col8" >57.5</td>
#     </tr>
#     <tr>
#       <th id="T_30db1_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_30db1_row1_col0" class="data row1 col0" >ViT (scratch, 1ch)</td>
#       <td id="T_30db1_row1_col1" class="data row1 col1" >0.148</td>
#       <td id="T_30db1_row1_col2" class="data row1 col2" >80.77%</td>
#       <td id="T_30db1_row1_col3" class="data row1 col3" >78.01%</td>
#       <td id="T_30db1_row1_col4" class="data row1 col4" >96.41%</td>
#       <td id="T_30db1_row1_col5" class="data row1 col5" >86.24%</td>
#       <td id="T_30db1_row1_col6" class="data row1 col6" >91.81%</td>
#       <td id="T_30db1_row1_col7" class="data row1 col7" >21.47</td>
#       <td id="T_30db1_row1_col8" class="data row1 col8" >63.3</td>
#     </tr>
#     <tr>
#       <th id="T_30db1_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_30db1_row2_col0" class="data row2 col0" >ResNet18 (scratch, 1ch)</td>
#       <td id="T_30db1_row2_col1" class="data row2 col1" >0.111</td>
#       <td id="T_30db1_row2_col2" class="data row2 col2" >79.97%</td>
#       <td id="T_30db1_row2_col3" class="data row2 col3" >76.45%</td>
#       <td id="T_30db1_row2_col4" class="data row2 col4" >98.21%</td>
#       <td id="T_30db1_row2_col5" class="data row2 col5" >85.97%</td>
#       <td id="T_30db1_row2_col6" class="data row2 col6" >91.71%</td>
#       <td id="T_30db1_row2_col7" class="data row2 col7" >11.17</td>
#       <td id="T_30db1_row2_col8" class="data row2 col8" >24.4</td>
#     </tr>
#   </tbody>
# </table>
# === Table B — Metrics at fixed threshold = 0.50 ===
# <style type="text/css">
# #T_cd75b_row0_col0, #T_cd75b_row0_col1, #T_cd75b_row0_col2, #T_cd75b_row0_col3, #T_cd75b_row0_col4, #T_cd75b_row0_col5, #T_cd75b_row0_col6, #T_cd75b_row0_col7, #T_cd75b_row0_col8, #T_cd75b_row1_col0, #T_cd75b_row1_col1, #T_cd75b_row1_col2, #T_cd75b_row1_col3, #T_cd75b_row1_col4, #T_cd75b_row1_col5, #T_cd75b_row1_col6, #T_cd75b_row1_col7, #T_cd75b_row1_col8, #T_cd75b_row2_col0, #T_cd75b_row2_col1, #T_cd75b_row2_col2, #T_cd75b_row2_col3, #T_cd75b_row2_col4, #T_cd75b_row2_col5, #T_cd75b_row2_col6, #T_cd75b_row2_col7, #T_cd75b_row2_col8 {
#   text-align: center;
# }
# </style>
# <table id="T_cd75b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cd75b_level0_col0" class="col_heading level0 col0" >model</th>
#       <th id="T_cd75b_level0_col1" class="col_heading level0 col1" >threshold</th>
#       <th id="T_cd75b_level0_col2" class="col_heading level0 col2" >acc</th>
#       <th id="T_cd75b_level0_col3" class="col_heading level0 col3" >precision</th>
#       <th id="T_cd75b_level0_col4" class="col_heading level0 col4" >recall</th>
#       <th id="T_cd75b_level0_col5" class="col_heading level0 col5" >f1</th>
#       <th id="T_cd75b_level0_col6" class="col_heading level0 col6" >auroc</th>
#       <th id="T_cd75b_level0_col7" class="col_heading level0 col7" >params (M)</th>
#       <th id="T_cd75b_level0_col8" class="col_heading level0 col8" >time (min)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cd75b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cd75b_row0_col0" class="data row0 col0" >CustomCNN (scratch, 1ch)</td>
#       <td id="T_cd75b_row0_col1" class="data row0 col1" >0.500</td>
#       <td id="T_cd75b_row0_col2" class="data row0 col2" >85.26%</td>
#       <td id="T_cd75b_row0_col3" class="data row0 col3" >88.80%</td>
#       <td id="T_cd75b_row0_col4" class="data row0 col4" >87.44%</td>
#       <td id="T_cd75b_row0_col5" class="data row0 col5" >88.11%</td>
#       <td id="T_cd75b_row0_col6" class="data row0 col6" >91.98%</td>
#       <td id="T_cd75b_row0_col7" class="data row0 col7" >0.48</td>
#       <td id="T_cd75b_row0_col8" class="data row0 col8" >57.5</td>
#     </tr>
#     <tr>
#       <th id="T_cd75b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_cd75b_row1_col0" class="data row1 col0" >ViT (scratch, 1ch)</td>
#       <td id="T_cd75b_row1_col1" class="data row1 col1" >0.500</td>
#       <td id="T_cd75b_row1_col2" class="data row1 col2" >84.46%</td>
#       <td id="T_cd75b_row1_col3" class="data row1 col3" >90.36%</td>
#       <td id="T_cd75b_row1_col4" class="data row1 col4" >84.10%</td>
#       <td id="T_cd75b_row1_col5" class="data row1 col5" >87.12%</td>
#       <td id="T_cd75b_row1_col6" class="data row1 col6" >91.81%</td>
#       <td id="T_cd75b_row1_col7" class="data row1 col7" >21.47</td>
#       <td id="T_cd75b_row1_col8" class="data row1 col8" >63.3</td>
#     </tr>
#     <tr>
#       <th id="T_cd75b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_cd75b_row2_col0" class="data row2 col0" >ResNet18 (scratch, 1ch)</td>
#       <td id="T_cd75b_row2_col1" class="data row2 col1" >0.500</td>
#       <td id="T_cd75b_row2_col2" class="data row2 col2" >84.94%</td>
#       <td id="T_cd75b_row2_col3" class="data row2 col3" >89.57%</td>
#       <td id="T_cd75b_row2_col4" class="data row2 col4" >85.90%</td>
#       <td id="T_cd75b_row2_col5" class="data row2 col5" >87.70%</td>
#       <td id="T_cd75b_row2_col6" class="data row2 col6" >91.71%</td>
#       <td id="T_cd75b_row2_col7" class="data row2 col7" >11.17</td>
#       <td id="T_cd75b_row2_col8" class="data row2 col8" >24.4</td>
#     </tr>
#   </tbody>
# </table>
